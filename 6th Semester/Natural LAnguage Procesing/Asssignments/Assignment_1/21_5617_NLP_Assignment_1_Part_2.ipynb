# %% [markdown]
# # Language Models and Smoothing

# %% [markdown]
# # Impots Libraries

# %%
from collections import defaultdict
import random
import math
import os.path
import sys
from collections import defaultdict

# %% [markdown]
# ## Readfile

# %%
def readFileToCorpus(f):
    """ Reads in the text file f which contains one sentence per line.
    """
    if os.path.isfile(f):
        with open(f, "r", encoding="utf-8") as file:
            i = 0
            corpus = []
            print("Reading file ", f)
            for line in file:
                i += 1
                sentence = line.split()
                corpus.append(sentence)
                if i % 1000 == 0:
                    sys.stderr.write("Reading sentence " + str(i) + "\n")
        return corpus
    else:
        print("Error: corpus file ", f, " does not exist")
        sys.exit()

# %% [markdown]
# ## PreProcesing

# %%
# Constants
UNK = "UNK"
start = "<s>"
end = "</s>"

def preprocess(corpus):
    # Find all the rare words
    freqDict = defaultdict(int)
    for sen in corpus:
        for word in sen:
            freqDict[word] += 1

    # Replace rare words with UNK
    for sen in corpus:
        for i in range(len(sen)):
            word = sen[i]
            if freqDict[word] < 2:
                sen[i] = UNK

    # Bookend the sentences with start and end tokens
    for sen in corpus:
        sen.insert(0, start)
        sen.append(end)

    return corpus

def preprocessTest(vocab, corpus):
    # Replace test words that were unseen in the training with UNK
    for sen in corpus:
        for i in range(len(sen)):
            word = sen[i]
            if word not in vocab:
                sen[i] = UNK

    # Bookend the sentences with start and end tokens
    for sen in corpus:
        sen.insert(0, start)
        sen.append(end)

    return corpus

# %% [markdown]
# ## Base Language model

# %%
class LanguageModel:
    def __init__(self, corpus, **kwargs):
        self.smoothing_value_unigram = kwargs.get('smoothing_value_unigram', 1)
        self.smoothing_value_bigram = kwargs.get('smoothing_value_bigram', 0.5)
        self.unigram_dist = self.train_unigram(corpus)
        self.bigram_dist = self.train_bigram(corpus)
        self.smoothed_unigram_dist = self.train_smoothed_unigram(corpus)
        self.smoothed_bigram_dist = self.train_smoothed_bigram(corpus)

    def train_unigram(self, corpus):
        unigram_counts = defaultdict(int)
        total_words = 0

        for sentence in corpus:
            for word in sentence:
                unigram_counts[word] += 1
                total_words += 1

        unigram_dist = {word: count / total_words for word, count in unigram_counts.items()}
        return unigram_dist

    def train_bigram(self, corpus):
        bigram_counts = defaultdict(lambda: defaultdict(int))

        for sentence in corpus:
            for i in range(len(sentence) - 1):
                current_word = sentence[i]
                next_word = sentence[i + 1]

                bigram_counts[current_word][next_word] += 1

        bigram_dist = {word1: {word2: count for word2, count in bigram_counts[word1].items()} for word1 in bigram_counts}
        return bigram_dist

    def train_smoothed_unigram(self, corpus):
        unigram_counts = defaultdict(int)
        total_words = 0

        for sentence in corpus:
            for word in sentence:
                unigram_counts[word] += 1
                total_words += 1

        smoothed_unigram_dist = {word: (count + self.smoothing_value_unigram) / (total_words + self.smoothing_value_unigram * len(unigram_counts))
                                 for word, count in unigram_counts.items()}
        return smoothed_unigram_dist

    def train_smoothed_bigram(self, corpus):
        unigram_counts = defaultdict(int)
        bigram_counts = defaultdict(lambda: defaultdict(int))

        total_words = 0

        for sentence in corpus:
            for i in range(len(sentence)):
                word = sentence[i]
                unigram_counts[word] += 1
                total_words += 1

                if i < len(sentence) - 1:
                    next_word = sentence[i + 1]
                    bigram_counts[word][next_word] += 1

        smoothed_bigram_dist = {}
        for word1 in bigram_counts:
            total_bigrams = sum(bigram_counts[word1].values())
            smoothed_bigram_dist[word1] = defaultdict(float)
            for word2 in bigram_counts[word1]:
                prob = (1 - self.smoothing_value_bigram) * (bigram_counts[word1][word2] / unigram_counts[word1]) + \
                       self.smoothing_value_bigram * (unigram_counts[word2] / total_words)
                smoothed_bigram_dist[word1][word2] = prob

        return smoothed_bigram_dist


    def generateSentence(self):
        sentence = ['<s>']
        while True:
            # Assuming word1 is the last word in the sentence
            word1 = sentence[-1]
            
            # Corrected line for bigram model
            word2 = random.choices(
                list(self.bigram_dist.get(word1, {}).keys()),
                weights=list(self.bigram_dist.get(word1, {}).values())
            )[0]
            
            sentence.append(word2)
            
            # Break if the generated word is '</s>' or if sentence length exceeds 200
            if word2 == '</s>' or len(sentence) > 200: 
                break
        return sentence

    def getSentenceProbability(self, sen):
        probability = 1.0
        for word in sen:
            probability *= self.unigram_dist.get(word, 0)
        return probability

    def getSentenceProbabilityBigram(self, sentence):
        probability = 1.0
        for i in range(1, len(sentence)):
            bigram = (sentence[i-1], sentence[i])
            probability *= self.bigram_dist.get(bigram, 0)
        return probability

    def getCorpusPerplexity(self, corpus):
        total_log_prob = 0.0
        total_words = 0

        for sentence in corpus:
            for word in sentence:
                total_log_prob += -1 * self.unigram_dist.get(word, 0)
                total_words += 1

        avg_log_prob = total_log_prob / total_words
        perplexity = 2 ** (-avg_log_prob)  # Correcting the formula
        return perplexity

    def getCorpusPerplexityBigram(self, corpus):
        total_log_prob = 0.0
        total_bigrams = 0

        for sentence in corpus:
            # Assuming sentence is a list of words
            for i in range(1, len(sentence)):
                # Calculate bigram probability
                bigram = (sentence[i-1], sentence[i])
                total_log_prob += -1 * self.bigram_dist.get(bigram, 0)
                total_bigrams += 1

        avg_log_prob = total_log_prob / total_bigrams
        perplexity = 2 ** avg_log_prob
        return perplexity

    def generateSentencesToFile(self, numberOfSentences, filename, modelName):
        with open(filename, 'w+') as filePointer:
            print(modelName, file=filePointer)
            for i in range(numberOfSentences):
                sen = self.generateSentence()
                prob = self.getSentenceProbability(sen)

                stringGenerated = f"{prob} {' '.join(sen)}"
                print(stringGenerated, file=filePointer)

    def generateSentencesToFileBigram(self, numberOfSentences, filename, modelName):
        with open(filename, 'w+') as filePointer:
            print(modelName, file=filePointer)
            for i in range(numberOfSentences):
                sen = self.generateSentence()
                prob = self.getSentenceProbabilityBigram(sen)

                stringGenerated = f"{prob} {' '.join(sen)}"
                print(stringGenerated, file=filePointer)

# %% [markdown]
# ## UniGram Model Without Smoothing

# %%
class UnigramModel(LanguageModel):
    def __init__(self, corpus):
        super().__init__(corpus)

    def train_unigram(self, corpus):
        unigram_dist = super().train_unigram(corpus)
        return unigram_dist

    # Override the general generateSentence method
    def generateSentence(self):
        sentence = super().generateSentence()
        return sentence

    # Override the general getSentenceProbability method
    def getSentenceProbability(self, sen):
        probability = super().getSentenceProbability(sen)
        return probability

    # Override the general getCorpusPerplexity method
    def getCorpusPerplexity(self, corpus):
        perplexity = super().getCorpusPerplexity(corpus)
        return perplexity
    def generateSentencesToFile(self, numberOfSentences, filename,model):
        # Call the function from the parent class using super()
        super().generateSentencesToFile(numberOfSentences, filename,model)

# %% [markdown]
# ## Smoothed Unigram MOdel

# %%
class SmoothedUnigramModel(LanguageModel):
    def __init__(self, corpus):
        super().__init__(corpus)
        self.unigram_dist = self.train(corpus)

    def train(self, corpus):
        smoothed_unigram_dist = super().train_smoothed_unigram(corpus)
        return smoothed_unigram_dist

    # Override the general generateSentence method
    def generateSentence(self):
        sentence = super().generateSentence()
        return sentence

    # Override the general getSentenceProbability method
    def getSentenceProbability(self, sen):
        probability = super().getSentenceProbability(sen)
        return probability

    # Override the general getCorpusPerplexity method
    def getCorpusPerplexity(self, corpus):
        perplexity = super().getCorpusPerplexity(corpus)
        return perplexity

    def generateSentencesToFile(self, numberOfSentences, filename, model):
        # Call the function from the parent class using super()
        super().generateSentencesToFile(numberOfSentences, filename, model)

# %% [markdown]
# ## UN Smoothed BIgram Model

# %%
class UnsmoothedBigramModel(LanguageModel):
    def __init__(self, corpus):
        super().__init__(corpus)
        self.bigram_dist = self.train(corpus)

    def train(self, corpus):
        unsmoothed_bigram_dist =  super().train_bigram(corpus)
        return unsmoothed_bigram_dist

    def generateSentence(self):
        sentence = super().generateSentence()
        return sentence

    def getSentenceProbability(self, sen):
        probability = super().getSentenceProbabilityBigram(sen)
        return probability

    def getCorpusPerplexity(self, corpus):
        perplexity = super().getCorpusPerplexityBigram(corpus)
        return perplexity

    def generateSentencesToFile(self, numberOfSentences, filename, model):
        super().generateSentencesToFileBigram(numberOfSentences, filename, model)

# %% [markdown]
# ## Smoothed Bigram MOdel

# %%
class SmoothedBigramModelLI(LanguageModel):
    def __init__(self, corpus, **kwargs):
        super().__init__(corpus)
        self.bigram_dist = self.train(corpus, **kwargs)

    def train(self, corpus, **kwargs):
        smoothed_bigram_dist = super().train_smoothed_bigram(corpus)

        return smoothed_bigram_dist

    def generateSentence(self):
        sentence = super().generateSentence()
        return sentence

    def getSentenceProbability(self, sen):
        probability = super().getSentenceProbabilityBigram(sen)
        return probability

    def getCorpusPerplexity(self, corpus):
        perplexity = super().getCorpusPerplexityBigram(corpus)
        return perplexity

    def generateSentencesToFile(self, numberOfSentences, filename, model):
        super().generateSentencesToFileBigram(numberOfSentences, filename, model)

# %%
#-------------------------------------------
# The main routine
#-------------------------------------------
if __name__ == "__main__":

    trainCorpus = readFileToCorpus("D:/6th_Semester/NLP/Assignments/Assignment_1/train.txt")
    posTestCorpus = readFileToCorpus("D:/6th_Semester/NLP/Assignments/Assignment_1/neg_test.txt")
    negTestCorpus = readFileToCorpus("D:/6th_Semester/NLP/Assignments/Assignment_1/pos_test.txt")

    trainCorpus = preprocess(trainCorpus)


    # Create a unigram language model
    unigramModel = UnigramModel(trainCorpus)
    # Create Smoothed Language model 
    smoothed_model = SmoothedUnigramModel(trainCorpus)

    # Create  UnsmoothedBigramModel Language Model
    unsmoothed_bigram_model = UnsmoothedBigramModel(trainCorpus)

     # Create  smoothedBigramModel Language Model   
    smoothed_bigram_model_li = SmoothedBigramModelLI(trainCorpus, smoothing_value=0.5)


    vocab = set()
    for sentence in trainCorpus:
        for word in sentence:
            vocab.add(word)

    # Preprocess test corpora
    posTestCorpus = preprocessTest(vocab, posTestCorpus)
    negTestCorpus = preprocessTest(vocab, negTestCorpus)


    # Calculate the probability for each sentence in the test corpora Unigram 
    pos_sentence_probabilities_unigram = [unigramModel.getSentenceProbability(sentence) for sentence in posTestCorpus]
    neg_sentence_probabilities_unigram = [unigramModel.getSentenceProbability(sentence) for sentence in negTestCorpus]
    # Calculate the probability for each sentence in the test corpora smoothed Unigram 
    pos_sentence_probabilities_smoothed_unigram = [smoothed_model.getSentenceProbability(sentence) for sentence in posTestCorpus]
    neg_sentence_probabilities_smoothed_unigram = [smoothed_model.getSentenceProbability(sentence) for sentence in negTestCorpus]
    # Calculate the probability for each sentence in the test corpora BiUnigram 
    pos_sentence_probabilities_unsmoothed_bigram_model= [unsmoothed_bigram_model.getSentenceProbability(sentence) for sentence in posTestCorpus]
    neg_sentence_probabilities_unsmoothed_bigram_model = [unsmoothed_bigram_model.getSentenceProbability(sentence) for sentence in negTestCorpus]
    # Calculate the probability for each sentence in the test corpora smoothed Unigram 
    pos_sentence_probabilities_smoothed_BIunigram = [smoothed_bigram_model_li.getSentenceProbability(sentence) for sentence in posTestCorpus]
    neg_sentence_probabilities_smoothed_BIunigram = [smoothed_bigram_model_li.getSentenceProbability(sentence) for sentence in negTestCorpus]

    # Get corpus perplexity Unigram 
    corpus_perplexity_Uni = unigramModel.getCorpusPerplexity(trainCorpus)
    # Get corpus perplexity Smoothed Unigram 
    corpus_perplexity_S_Uni = smoothed_model.getCorpusPerplexity(trainCorpus)
    # Get corpus perplexity BIgram 
    corpus_perplexity_BI = unsmoothed_bigram_model.getCorpusPerplexity(trainCorpus)
    # Get corpus perplexity Smoothed Bigram 
    corpus_perplexity_S_BI = smoothed_bigram_model_li.getCorpusPerplexity(trainCorpus)


    smoothed_model = SmoothedUnigramModel(trainCorpus)
    print("\n---------------UN Smoothed Unigram Model Result --------------------------------------------------\n")
    print(unigramModel.unigram_dist)
    print("\n--------------- Smoothed Unigram Model Result --------------------------------------------------\n")
    print(smoothed_model.unigram_dist)
    print("\n---------------UN Smoothed Biigram Model Result --------------------------------------------------\n")

    for word1, word2_counts in list(unsmoothed_bigram_model.bigram_dist.items())[:5]:
        print(f"Bigram pairs for '{word1}': {word2_counts}")
    print("\n--------------- Smoothed Bigram Model Result --------------------------------------------------\n")
    for word1, word2_dict in list(smoothed_bigram_model_li.bigram_dist.items())[:5]:
        print(f"Bigram pairs for '{word1}': {word2_dict}")

    print("\n\n---------------------Test Sentences -------------------------------------------------------\n")    

    # Print UniGRam sentence probabilities for positive test corpus
    print("\n\n----------------  Unigram sentence Positive Test Corpus Sentence Probabilities:-------------\n")
    for i, probability in enumerate(pos_sentence_probabilities_unigram):
        print(f"Sentence {i + 1} Probability: {probability}")

    # Print Unigram sentence probabilities for negative test corpus
    print("\n----------------- Unigram sentence Negative Test Corpus Sentence Probabilities:----------------------\n")
    for i, probability in enumerate(neg_sentence_probabilities_unigram):
        print(f"Sentence {i + 1} Probability: {probability}")



    # Print smoothed UniGRam sentence probabilities for positive test corpus
    print("\n--------------------------------- smoothed Unigram sentence Positive Test Corpus Sentence Probabilities:----------------------------\n")
    for i, probability in enumerate(pos_sentence_probabilities_smoothed_unigram):
        print(f"Sentence {i + 1} Probability: {probability}")

    # Print smoothed Unigram sentence probabilities for negative test corpus
    print(" \n---------------------smoothed Unigram sentence Negative Test Corpus Sentence Probabilities:----------------------\n")
    for i, probability in enumerate(neg_sentence_probabilities_smoothed_unigram):
        print(f"Sentence {i + 1} Probability: {probability}")


    # Print  BIiGRam sentence probabilities for positive test corpus
    print(" \n---------------------------- BIigram sentence Positive Test Corpus Sentence Probabilities:-----------------------------\n")
    for i, probability in enumerate(pos_sentence_probabilities_unsmoothed_bigram_model):
        print(f"Sentence {i + 1} Probability: {probability}")

    # Print  BIigram sentence probabilities for negative test corpus
    print("\n------------------------------------ BIigram sentence Negative Test Corpus Sentence Probabilities:-----------------------------\n")
    for i, probability in enumerate(neg_sentence_probabilities_unsmoothed_bigram_model):
        print(f"Sentence {i + 1} Probability: {probability}")


    # Print Smoothed  BIiGRam sentence probabilities for positive test corpus
    print(" \n----------------------------Smoothed  BIigram sentence Positive Test Corpus Sentence Probabilities:-----------------------------\n")
    for i, probability in enumerate(pos_sentence_probabilities_smoothed_BIunigram):
        print(f"Sentence {i + 1} Probability: {probability}")

    # Print Smoothed BIigram sentence probabilities for negative test corpus
    print("\n------------------------------------Smoothed BIigram sentence Negative Test Corpus Sentence Probabilities:-----------------------------\n")
    for i, probability in enumerate( neg_sentence_probabilities_smoothed_BIunigram):
        print(f"Sentence {i + 1} Probability: {probability}")


    print("\n Uni Gram Corpus Perplexity:", corpus_perplexity_Uni)
    print("\n Smoothed Uni Gram Corpus Perplexity:", corpus_perplexity_S_Uni)
    print("\n BI Gram Corpus Perplexity:", corpus_perplexity_BI)
    print("\n Smoothed BI Gram Corpus Perplexity:", corpus_perplexity_S_BI)
    unigramModel.generateSentencesToFile(5, 'D:/6th_Semester/NLP/Assignments/Assignment_1/Results.txt','unigramModel')
    smoothed_model.generateSentencesToFile(5, 'D:/6th_Semester/NLP/Assignments/Assignment_1/Results.txt','smoothed unigramModel')
    unsmoothed_bigram_model.generateSentencesToFile(5, 'D:/6th_Semester/NLP/Assignments/Assignment_1/Results.txt','unsmoothed_bigram_model')
    smoothed_bigram_model_li.generateSentencesToFile(5, 'D:/6th_Semester/NLP/Assignments/Assignment_1/Results.txt','smoothed_bigram_model')
# Out:
# Reading file  D:/6th_Semester/NLP/Assignments/Assignment_1/train.txt
# Reading sentence 1000
497, 'strip': 0.0049841156822338925, 'episodes': 0.0025016913812502743, 'payoffs': 0.0024888466610725034, 'creativity': 0.002493984549143612, 'figure': 0.002533160945685813, 'caricature': 0.002495269021161389, 'success': 0.0025607770940680205, 'tone': 0.0025280230576147046, 'trick': 0.0024984802012058315, 'piece': 0.002558850386041355, 'partner': 0.002511967157392491, 'terror': 0.0025055447973036057, 'touches': 0.002511967157392491, 'sidekick': 0.0025010491452413857, 'dynamite': 0.0024888466610725034, 'arc': 0.0024914156051080577, 'characterizations': 0.0024946267851525005, 'dueling': 0.0024901311330902806, 'performances': 0.0026526168433390826, 'abilities': 0.002496553493179166, 'kevin': 0.0025639882741124633, 'expression': 0.0025016913812502743, 'maturity': 0.0024946267851525005, 'bard': 0.004978977794162784, 'henchman': 0.0024901311330902806, 'aspects': 0.0025203162255080422, 'masterpiece': 0.002527380821605816, 'gift': 0.0025061870333124943, 'interludes': 0.002490773369099169, 'john': 0.0027251895123434886, 'actress': 0.0025395833057746987, 'brew': 0.0024901311330902806})
#
#
# ---------------------Test Sentences -------------------------------------------------------
#
#
#
# ----------------  Unigram sentence Positive Test Corpus Sentence Probabilities:-------------
#
# Sentence 1 Probability: 5.448055670122837e-53
# Sentence 2 Probability: 6.332664723168506e-20
# Sentence 3 Probability: 1.2810275385954317e-57
# Sentence 4 Probability: 2.187468345198287e-15
# Sentence 5 Probability: 4.905391723502733e-32
# Sentence 6 Probability: 2.6086171661149557e-75
# Sentence 7 Probability: 2.37033016732701e-185
# Sentence 8 Probability: 4.479825815875037e-49
# Sentence 9 Probability: 3.129024910764342e-25
# Sentence 10 Probability: 3.6676373305218087e-38
# Sentence 11 Probability: 3.975400366927395e-86
# Sentence 12 Probability: 4.641044069459584e-153
# Sentence 13 Probability: 2.5011914120161108e-136
# Sentence 14 Probability: 4.497137743341306e-75
# Sentence 15 Probability: 1.0287929013748532e-48
# Sentence 16 Probability: 1.787590880645225e-10
# Sentence 17 Probability: 4.499440762822413e-161
# Sentence 18 Probability: 3.2745206880148087e-108
# Sentence 19 Probability: 1.4812361770026868e-77
# Sentence 20 Probability: 5.134709068589395e-24
# Sentence 21 Probability: 9.20162693026165e-36
# Sentence 22 Probability: 6.188308243658911e-37
# Sentence 23 Probability: 3.6554004081614338e-65
# Sentence 24 Probability: 8.714894726746026e-57
# Sentence 25 Probability: 1.0119952198514242e-106
# Sentence 26 Probability: 1.5476761418133492e-101
# Sentence 27 Probability: 1.7072759740458917e-76
# Sentence 28 Probability: 3.39813526168355e-127
# Sentence 29 Probability: 2.1799044542447277e-52
# Sentence 30 Probability: 9.635198461367173e-61
# Sentence 31 Probability: 3.2168828339031277e-55
# Sentence 32 Probability: 5.174255832719256e-17
# Sentence 33 Probability: 8.26825227208133e-09
# Sentence 34 Probability: 3.6540318682746013e-22
# Sentence 35 Probability: 3.924357044279992e-179
# Sentence 36 Probability: 4.053414398238915e-24
# Sentence 37 Probability: 1.0786982758521084e-17
# Sentence 38 Probability: 1.166197834332474e-157
# Sentence 39 Probability: 1.32270424059475e-28
# Sentence 40 Probability: 4.563684315698164e-94
# Sentence 41 Probability: 2.7668018101534854e-160
# Sentence 42 Probability: 2.8691571038244135e-52
# Sentence 43 Probability: 1.429745329245766e-38
# Sentence 44 Probability: 1.0553734937240329e-44
# Sentence 45 Probability: 1.1547170669881836e-49
# Sentence 46 Probability: 6.326121440298916e-85
# Sentence 47 Probability: 2.165226150763681e-49
# Sentence 48 Probability: 4.3143553068234206e-36
# Sentence 49 Probability: 6.413971525876259e-60
# Sentence 50 Probability: 4.512609288833522e-103
# Sentence 51 Probability: 3.7206915434572743e-53
# Sentence 52 Probability: 2.098237291646326e-37
# Sentence 53 Probability: 2.279225253467727e-78
# Sentence 54 Probability: 2.9029909324212972e-30
# Sentence 55 Probability: 1.331859249331962e-43
# Sentence 56 Probability: 5.037133619962929e-73
# Sentence 57 Probability: 1.6413875406543715e-87
# Sentence 58 Probability: 7.87236019372276e-29
# Sentence 59 Probability: 1.5315897525335627e-83
# Sentence 60 Probability: 5.199351279173301e-44
# Sentence 61 Probability: 2.425052760200282e-73
# Sentence 62 Probability: 4.3979321705957665e-83
# Sentence 63 Probability: 4.027744682987976e-77
# Sentence 64 Probability: 1.9153545438791566e-80
# Sentence 65 Probability: 2.518780919963011e-74
# Sentence 66 Probability: 5.247195414910999e-103
# Sentence 67 Probability: 6.861222029913491e-71
# Sentence 68 Probability: 2.8144222869445517e-160
# Sentence 69 Probability: 1.5936756264654726e-70
# Sentence 70 Probability: 6.280733143051189e-104
# Sentence 71 Probability: 9.865960470597188e-24
# Sentence 72 Probability: 2.0755854554498703e-107
# Sentence 73 Probability: 2.0967049698311673e-166
# Sentence 74 Probability: 1.3029109405793987e-60
# Sentence 75 Probability: 2.4979020466580012e-86
# Sentence 76 Probability: 5.294157075477869e-84
# Sentence 77 Probability: 2.5628793956223238e-138
# Sentence 78 Probability: 1.4335357342915412e-157
# Sentence 79 Probability: 6.302443687422133e-82
# Sentence 80 Probability: 4.750112929875546e-95
# Sentence 81 Probability: 2.7910567402431653e-43
# Sentence 82 Probability: 7.606335069838496e-20
# Sentence 83 Probability: 2.5648809086940895e-77
# Sentence 84 Probability: 2.626248735289889e-34
# Sentence 85 Probability: 1.0709643303317136e-57
# Sentence 86 Probability: 1.8524106806889492e-81
# Sentence 87 Probability: 1.542370885117378e-179
# Sentence 88 Probability: 9.133677483488703e-45
# Sentence 89 Probability: 4.961594610459166e-99
# Sentence 90 Probability: 1.2006025700676966e-43
# Sentence 91 Probability: 6.647813068134219e-94
# Sentence 92 Probability: 1.1772720488561064e-70
# Sentence 93 Probability: 3.7707467448828747e-100
# Sentence 94 Probability: 8.739748609791161e-138
# Sentence 95 Probability: 1.9070368055644734e-122
# Sentence 96 Probability: 1.480525112639526e-84
# Sentence 97 Probability: 5.504031728358951e-51
# Sentence 98 Probability: 6.149094295064582e-123
# Sentence 99 Probability: 1.1926995013403895e-34
# Sentence 100 Probability: 2.1153729624259063e-60
# Sentence 101 Probability: 5.022538883935608e-34
# Sentence 102 Probability: 8.98570980971252e-63
# Sentence 103 Probability: 3.0918004036909896e-56
# Sentence 104 Probability: 1.7058374740439938e-45
# Sentence 105 Probability: 2.0209338155368222e-54
# Sentence 106 Probability: 9.465267192557799e-47
# Sentence 107 Probability: 3.082071407668049e-47
# Sentence 108 Probability: 4.6046166736956444e-45
# Sentence 109 Probability: 1.6962608757341063e-57
# Sentence 110 Probability: 2.8788544054528366e-52
# Sentence 111 Probability: 1.3263429734318773e-108
# Sentence 112 Probability: 1.127489751379674e-61
# Sentence 113 Probability: 4.018482871123631e-46
# Sentence 114 Probability: 5.384927020930777e-75
# Sentence 115 Probability: 6.587827730663404e-142
# Sentence 116 Probability: 1.0952981226154775e-44
# Sentence 117 Probability: 5.367508777212477e-42
# Sentence 118 Probability: 1.5887345916550466e-81
# Sentence 119 Probability: 3.060362746286719e-42
# Sentence 120 Probability: 1.5501500974159044e-12
# Sentence 121 Probability: 1.2583165579162863e-40
# Sentence 122 Probability: 3.6676307347883747e-56
# Sentence 123 Probability: 2.209966857102046e-82
# Sentence 124 Probability: 5.078874462751788e-72
# Sentence 125 Probability: 2.2200032045017726e-83
# Sentence 126 Probability: 6.096712772564213e-90
# Sentence 127 Probability: 3.1028655860506664e-52
# Sentence 128 Probability: 3.7131873039132485e-68
# Sentence 129 Probability: 1.1242806823768409e-41
# Sentence 130 Probability: 4.229648001618088e-92
# Sentence 131 Probability: 2.43731675007288e-26
# Sentence 132 Probability: 1.897053521858962e-64
# Sentence 133 Probability: 4.6545200587734286e-67
# Sentence 134 Probability: 3.1413935240507482e-78
# Sentence 135 Probability: 1.905546506979848e-69
# Sentence 136 Probability: 2.139589038613536e-68
# Sentence 137 Probability: 5.06411239116801e-85
# Sentence 138 Probability: 6.297640451312251e-42
# Sentence 139 Probability: 1.1194650711298136e-30
# Sentence 140 Probability: 2.225462969977189e-80
# Sentence 141 Probability: 2.823423735649189e-66
# Sentence 142 Probability: 4.51517489724601e-48
# Sentence 143 Probability: 1.6551702728547544e-50
# Sentence 144 Probability: 1.080939115442527e-43
# Sentence 145 Probability: 2.1971882928495073e-98
# Sentence 146 Probability: 9.242262492559129e-141
# Sentence 147 Probability: 8.138747751782589e-57
# Sentence 148 Probability: 1.1982810358870147e-53
# Sentence 149 Probability: 3.5392902981966704e-90
# Sentence 150 Probability: 9.79625621515185e-60
# Sentence 151 Probability: 1.4645527267784173e-72
# Sentence 152 Probability: 3.0766490686591836e-94
# Sentence 153 Probability: 2.7743098787920257e-34
# Sentence 154 Probability: 2.13362960064949e-60
# Sentence 155 Probability: 8.532215733729683e-102
# Sentence 156 Probability: 1.3400072992658548e-59
# Sentence 157 Probability: 2.891692714461362e-47
# Sentence 158 Probability: 1.1371275549872595e-71
# Sentence 159 Probability: 5.735640400687108e-69
# Sentence 160 Probability: 3.529660648232629e-74
# Sentence 161 Probability: 4.2922484657108116e-89
# Sentence 162 Probability: 1.0646918936114357e-35
# Sentence 163 Probability: 6.26005229037749e-49
# Sentence 164 Probability: 1.5368402206755542e-86
# Sentence 165 Probability: 4.450775936998813e-132
# Sentence 166 Probability: 1.0309551150192417e-86
# Sentence 167 Probability: 1.5553031531510032e-62
# Sentence 168 Probability: 9.356554583886553e-46
# Sentence 169 Probability: 7.290181914883463e-111
# Sentence 170 Probability: 8.548351916585292e-31
# Sentence 171 Probability: 6.161483460947371e-11
# Sentence 172 Probability: 1.3570304656918318e-72
# Sentence 173 Probability: 3.258393415811363e-44
# Sentence 174 Probability: 5.50267658064227e-88
# Sentence 175 Probability: 1.9406308060505956e-12
# Sentence 176 Probability: 2.2530205601609105e-38
# Sentence 177 Probability: 1.1147211000476818e-140
# Sentence 178 Probability: 7.391043299082351e-106
# Sentence 179 Probability: 4.2432573813923054e-26
# Sentence 180 Probability: 5.079330457308753e-39
# Sentence 181 Probability: 1.629353374147405e-82
# Sentence 182 Probability: 6.885286799703803e-67
# Sentence 183 Probability: 4.163343233819426e-125
# Sentence 184 Probability: 2.267516802717706e-51
# Sentence 185 Probability: 1.2948908127638542e-114
# Sentence 186 Probability: 1.4981825710163283e-66
# Sentence 187 Probability: 3.363141052673152e-123
# Sentence 188 Probability: 1.5134242676480924e-81
# Sentence 189 Probability: 1.2156709087620796e-44
# Sentence 190 Probability: 3.8830248502761103e-31
# Sentence 191 Probability: 1.601660966587975e-34
# Sentence 192 Probability: 3.4138418167901423e-69
# Sentence 193 Probability: 4.2030899724517205e-73
# Sentence 194 Probability: 2.086188547661035e-31
# Sentence 195 Probability: 2.9312462499968667e-42
# Sentence 196 Probability: 1.7068008339313723e-280
# Sentence 197 Probability: 1.1316878049815903e-50
# Sentence 198 Probability: 6.296274148221762e-32
# Sentence 199 Probability: 4.6891973327560145e-20
# Sentence 200 Probability: 3.036879183715555e-35
# Sentence 201 Probability: 2.113847706437503e-28
# Sentence 202 Probability: 1.0123478634299752e-96
# Sentence 203 Probability: 2.856992639529282e-29
# Sentence 204 Probability: 6.577961437576198e-146
# Sentence 205 Probability: 3.425474056061122e-75
# Sentence 206 Probability: 2.846613446092434e-79
# Sentence 207 Probability: 7.839371868249353e-155
# Sentence 208 Probability: 3.1158849714057735e-115
# Sentence 209 Probability: 5.513239230804666e-79
# Sentence 210 Probability: 3.791574744382009e-46
# Sentence 211 Probability: 1.9345656468034233e-140
# Sentence 212 Probability: 1.0912705154095197e-90
# Sentence 213 Probability: 1.482167299301375e-133
# Sentence 214 Probability: 1.8140741867177794e-47
# Sentence 215 Probability: 5.504148005155865e-59
# Sentence 216 Probability: 1.2004819245966723e-37
# Sentence 217 Probability: 1.4766316072594439e-33
# Sentence 218 Probability: 7.148151683033283e-92
# Sentence 219 Probability: 3.128349770518912e-76
# Sentence 220 Probability: 6.292719968931397e-89
# Sentence 221 Probability: 9.940556823631697e-129
# Sentence 222 Probability: 1.0799154194035087e-139
# Sentence 223 Probability: 5.181812643799352e-46
# Sentence 224 Probability: 2.227365860533505e-24
# Sentence 225 Probability: 6.556606732521757e-52
# Sentence 226 Probability: 1.624978644110317e-108
# Sentence 227 Probability: 9.122251308211832e-61
# Sentence 228 Probability: 3.416726891367385e-78
# Sentence 229 Probability: 1.8203289414099203e-19
# Sentence 230 Probability: 3.7665632785753626e-196
# Sentence 231 Probability: 1.9392733861571613e-109
# Sentence 232 Probability: 3.5970593191571696e-34
# Sentence 233 Probability: 1.1175478795556739e-24
# Sentence 234 Probability: 1.0715470800243191e-30
# Sentence 235 Probability: 4.581541338738781e-145
# Sentence 236 Probability: 1.7391767838273878e-59
# Sentence 237 Probability: 9.942659198154708e-82
# Sentence 238 Probability: 4.0455201779423916e-66
# Sentence 239 Probability: 3.1535916143702825e-82
# Sentence 240 Probability: 5.375587736344731e-36
# Sentence 241 Probability: 2.6658152250089858e-52
# Sentence 242 Probability: 6.188398829803103e-82
# Sentence 243 Probability: 3.2745320162829884e-124
# Sentence 244 Probability: 2.268462664860288e-79
# Sentence 245 Probability: 5.89500105183114e-91
# Sentence 246 Probability: 5.377716726164797e-55
# Sentence 247 Probability: 3.0648652524248356e-52
# Sentence 248 Probability: 1.857455726624507e-114
# Sentence 249 Probability: 1.5089995667842349e-33
# Sentence 250 Probability: 5.327343668600252e-66
# Sentence 251 Probability: 2.533622286586264e-19
# Sentence 252 Probability: 2.1386552696449817e-72
# Sentence 253 Probability: 7.7328487121470365e-56
# Sentence 254 Probability: 2.5102598016269385e-27
# ...
# Sentence 474 Probability: 0.0
# Sentence 475 Probability: 0.0
# Sentence 476 Probability: 0.0
# Sentence 477 Probability: 0.0
# Sentence 478 Probability: 0.0
# Sentence 479 Probability: 0.0
# Sentence 480 Probability: 0.0
# Sentence 481 Probability: 0.0
# Sentence 482 Probability: 0.0
# Sentence 483 Probability: 0.0
# Sentence 484 Probability: 0.0
# Sentence 485 Probability: 0.0
# Sentence 486 Probability: 0.0
# Sentence 487 Probability: 0.0
# Sentence 488 Probability: 0.0
# Sentence 489 Probability: 0.0
# Sentence 490 Probability: 0.0
# Sentence 491 Probability: 0.0
# Sentence 492 Probability: 0.0
# Sentence 493 Probability: 0.0
# Sentence 494 Probability: 0.0
# Sentence 495 Probability: 0.0
# Sentence 496 Probability: 0.0
# Sentence 497 Probability: 0.0
# Sentence 498 Probability: 0.0
# Sentence 499 Probability: 0.0
# Sentence 500 Probability: 0.0
# Sentence 501 Probability: 0.0
# Sentence 502 Probability: 0.0
# Sentence 503 Probability: 0.0
# Sentence 504 Probability: 0.0
# Sentence 505 Probability: 0.0
# Sentence 506 Probability: 0.0
# Sentence 507 Probability: 0.0
# Sentence 508 Probability: 0.0
# Sentence 509 Probability: 0.0
# Sentence 510 Probability: 0.0
# Sentence 511 Probability: 0.0
# Sentence 512 Probability: 0.0
# Sentence 513 Probability: 0.0
# Sentence 514 Probability: 0.0
# Sentence 515 Probability: 0.0
# Sentence 516 Probability: 0.0
# Sentence 517 Probability: 0.0
# Sentence 518 Probability: 0.0
# Sentence 519 Probability: 0.0
# Sentence 520 Probability: 0.0
# Sentence 521 Probability: 0.0
# Sentence 522 Probability: 0.0
# Sentence 523 Probability: 0.0
# Sentence 524 Probability: 0.0
# Sentence 525 Probability: 0.0
# Sentence 526 Probability: 0.0
# Sentence 527 Probability: 0.0
# Sentence 528 Probability: 0.0
# Sentence 529 Probability: 0.0
# Sentence 530 Probability: 0.0
# Sentence 531 Probability: 0.0
# Sentence 532 Probability: 0.0
# Sentence 533 Probability: 0.0
# Sentence 534 Probability: 0.0
# Sentence 535 Probability: 0.0
# Sentence 536 Probability: 0.0
# Sentence 537 Probability: 0.0
# Sentence 538 Probability: 0.0
# Sentence 539 Probability: 0.0
# Sentence 540 Probability: 0.0
# Sentence 541 Probability: 0.0
# Sentence 542 Probability: 0.0
# Sentence 543 Probability: 0.0
# Sentence 544 Probability: 0.0
# Sentence 545 Probability: 0.0
# Sentence 546 Probability: 0.0
# Sentence 547 Probability: 0.0
# Sentence 548 Probability: 0.0
# Sentence 549 Probability: 0.0
# Sentence 550 Probability: 0.0
# Sentence 551 Probability: 0.0
# Sentence 552 Probability: 0.0
# Sentence 553 Probability: 0.0
# Sentence 554 Probability: 0.0
# Sentence 555 Probability: 0.0
# Sentence 556 Probability: 0.0
# Sentence 557 Probability: 0.0
# Sentence 558 Probability: 0.0
# Sentence 559 Probability: 0.0
# Sentence 560 Probability: 0.0
# Sentence 561 Probability: 0.0
# Sentence 562 Probability: 0.0
# Sentence 563 Probability: 0.0
# Sentence 564 Probability: 0.0
# Sentence 565 Probability: 0.0
# Sentence 566 Probability: 0.0
# Sentence 567 Probability: 0.0
# Sentence 568 Probability: 0.0
# Sentence 569 Probability: 0.0
# Sentence 570 Probability: 0.0
# Sentence 571 Probability: 0.0
# Sentence 572 Probability: 0.0
# Sentence 573 Probability: 0.0
# Sentence 574 Probability: 0.0
# Sentence 575 Probability: 0.0
# Sentence 576 Probability: 0.0
# Sentence 577 Probability: 0.0
# Sentence 578 Probability: 0.0
# Sentence 579 Probability: 0.0
# Sentence 580 Probability: 0.0
# Sentence 581 Probability: 0.0
# Sentence 582 Probability: 0.0
# Sentence 583 Probability: 0.0
# Sentence 584 Probability: 0.0
# Sentence 585 Probability: 0.0
# Sentence 586 Probability: 0.0
# Sentence 587 Probability: 0.0
# Sentence 588 Probability: 0.0
# Sentence 589 Probability: 0.0
# Sentence 590 Probability: 0.0
# Sentence 591 Probability: 0.0
# Sentence 592 Probability: 0.0
# Sentence 593 Probability: 0.0
# Sentence 594 Probability: 0.0
# Sentence 595 Probability: 0.0
# Sentence 596 Probability: 0.0
# Sentence 597 Probability: 0.0
# Sentence 598 Probability: 0.0
# Sentence 599 Probability: 0.0
# Sentence 600 Probability: 0.0
# Sentence 601 Probability: 0.0
# Sentence 602 Probability: 0.0
# Sentence 603 Probability: 0.0
# Sentence 604 Probability: 0.0
# Sentence 605 Probability: 0.0
# Sentence 606 Probability: 0.0
# Sentence 607 Probability: 0.0
# Sentence 608 Probability: 0.0
# Sentence 609 Probability: 0.0
# Sentence 610 Probability: 0.0
# Sentence 611 Probability: 0.0
# Sentence 612 Probability: 0.0
# Sentence 613 Probability: 0.0
# Sentence 614 Probability: 0.0
# Sentence 615 Probability: 0.0
# Sentence 616 Probability: 0.0
# Sentence 617 Probability: 0.0
# Sentence 618 Probability: 0.0
# Sentence 619 Probability: 0.0
# Sentence 620 Probability: 0.0
# Sentence 621 Probability: 0.0
# Sentence 622 Probability: 0.0
# Sentence 623 Probability: 0.0
# Sentence 624 Probability: 0.0
# Sentence 625 Probability: 0.0
# Sentence 626 Probability: 0.0
# Sentence 627 Probability: 0.0
# Sentence 628 Probability: 0.0
# Sentence 629 Probability: 0.0
# Sentence 630 Probability: 0.0
# Sentence 631 Probability: 0.0
# Sentence 632 Probability: 0.0
# Sentence 633 Probability: 0.0
# Sentence 634 Probability: 0.0
# Sentence 635 Probability: 0.0
# Sentence 636 Probability: 0.0
# Sentence 637 Probability: 0.0
# Sentence 638 Probability: 0.0
# Sentence 639 Probability: 0.0
# Sentence 640 Probability: 0.0
# Sentence 641 Probability: 0.0
# Sentence 642 Probability: 0.0
# Sentence 643 Probability: 0.0
# Sentence 644 Probability: 0.0
# Sentence 645 Probability: 0.0
# Sentence 646 Probability: 0.0
# Sentence 647 Probability: 0.0
# Sentence 648 Probability: 0.0
# Sentence 649 Probability: 0.0
# Sentence 650 Probability: 0.0
# Sentence 651 Probability: 0.0
# Sentence 652 Probability: 0.0
# Sentence 653 Probability: 0.0
# Sentence 654 Probability: 0.0
# Sentence 655 Probability: 0.0
# Sentence 656 Probability: 0.0
# Sentence 657 Probability: 0.0
# Sentence 658 Probability: 0.0
# Sentence 659 Probability: 0.0
# Sentence 660 Probability: 0.0
# Sentence 661 Probability: 0.0
# Sentence 662 Probability: 0.0
# Sentence 663 Probability: 0.0
# Sentence 664 Probability: 0.0
# Sentence 665 Probability: 0.0
# Sentence 666 Probability: 0.0
# Sentence 667 Probability: 0.0
# Sentence 668 Probability: 0.0
# Sentence 669 Probability: 0.0
# Sentence 670 Probability: 0.0
# Sentence 671 Probability: 0.0
# Sentence 672 Probability: 0.0
# Sentence 673 Probability: 0.0
# Sentence 674 Probability: 0.0
# Sentence 675 Probability: 0.0
# Sentence 676 Probability: 0.0
# Sentence 677 Probability: 0.0
# Sentence 678 Probability: 0.0
# Sentence 679 Probability: 0.0
# Sentence 680 Probability: 0.0
# Sentence 681 Probability: 0.0
# Sentence 682 Probability: 0.0
# Sentence 683 Probability: 0.0
# Sentence 684 Probability: 0.0
# Sentence 685 Probability: 0.0
# Sentence 686 Probability: 0.0
# Sentence 687 Probability: 0.0
# Sentence 688 Probability: 0.0
# Sentence 689 Probability: 0.0
# Sentence 690 Probability: 0.0
# Sentence 691 Probability: 0.0
# Sentence 692 Probability: 0.0
# Sentence 693 Probability: 0.0
# Sentence 694 Probability: 0.0
# Sentence 695 Probability: 0.0
# Sentence 696 Probability: 0.0
# Sentence 697 Probability: 0.0
# Sentence 698 Probability: 0.0
# Sentence 699 Probability: 0.0
# Sentence 700 Probability: 0.0
# Sentence 701 Probability: 0.0
# Sentence 702 Probability: 0.0
# Sentence 703 Probability: 0.0
# Sentence 704 Probability: 0.0
# Sentence 705 Probability: 0.0
# Sentence 706 Probability: 0.0
# Sentence 707 Probability: 0.0
# Sentence 708 Probability: 0.0
# Sentence 709 Probability: 0.0
# Sentence 710 Probability: 0.0
# Sentence 711 Probability: 0.0
# Sentence 712 Probability: 0.0
# Sentence 713 Probability: 0.0
# Sentence 714 Probability: 0.0
# Sentence 715 Probability: 0.0
# Sentence 716 Probability: 0.0
# Sentence 717 Probability: 0.0
# Sentence 718 Probability: 0.0
# Sentence 719 Probability: 0.0
# Sentence 720 Probability: 0.0
# Sentence 721 Probability: 0.0
# Sentence 722 Probability: 0.0
# Sentence 723 Probability: 0.0
# Sentence 724 Probability: 0.0
# Sentence 725 Probability: 0.0
# Sentence 726 Probability: 0.0
# Sentence 727 Probability: 0.0
# Sentence 728 Probability: 0.0
# Sentence 729 Probability: 0.0
# Sentence 730 Probability: 0.0
# Sentence 731 Probability: 0.0
# Sentence 732 Probability: 0.0
# Sentence 733 Probability: 0.0
# Sentence 734 Probability: 0.0
# Sentence 735 Probability: 0.0
# Sentence 736 Probability: 0.0
# Sentence 737 Probability: 0.0
# Sentence 738 Probability: 0.0
# Sentence 739 Probability: 0.0
# Sentence 740 Probability: 0.0
# Sentence 741 Probability: 0.0
# Sentence 742 Probability: 0.0
# Sentence 743 Probability: 0.0
# Sentence 744 Probability: 0.0
# Sentence 745 Probability: 0.0
# Sentence 746 Probability: 0.0
# Sentence 747 Probability: 0.0
# Sentence 748 Probability: 0.0
# Sentence 749 Probability: 0.0
# Sentence 750 Probability: 0.0
# Sentence 751 Probability: 0.0
# Sentence 752 Probability: 0.0
# Sentence 753 Probability: 0.0
# Sentence 754 Probability: 0.0
# Sentence 755 Probability: 0.0
# Sentence 756 Probability: 0.0
# Sentence 757 Probability: 0.0
# Sentence 758 Probability: 0.0
# Sentence 759 Probability: 0.0
# Sentence 760 Probability: 0.0
# Sentence 761 Probability: 0.0
# Sentence 762 Probability: 0.0
# Sentence 763 Probability: 0.0
# Sentence 764 Probability: 0.0
# Sentence 765 Probability: 0.0
# Sentence 766 Probability: 0.0
# Sentence 767 Probability: 0.0
# Sentence 768 Probability: 0.0
# Sentence 769 Probability: 0.0
# Sentence 770 Probability: 0.0
# Sentence 771 Probability: 0.0
# Sentence 772 Probability: 0.0
# Sentence 773 Probability: 0.0
# Sentence 774 Probability: 0.0
# Sentence 775 Probability: 0.0
# Sentence 776 Probability: 0.0
# Sentence 777 Probability: 0.0
# Sentence 778 Probability: 0.0
# Sentence 779 Probability: 0.0
# Sentence 780 Probability: 0.0
# Sentence 781 Probability: 0.0
# Sentence 782 Probability: 0.0
# Sentence 783 Probability: 0.0
# Sentence 784 Probability: 0.0
# Sentence 785 Probability: 0.0
# Sentence 786 Probability: 0.0
# Sentence 787 Probability: 0.0
# Sentence 788 Probability: 0.0
# Sentence 789 Probability: 0.0
# Sentence 790 Probability: 0.0
# Sentence 791 Probability: 0.0
# Sentence 792 Probability: 0.0
# Sentence 793 Probability: 0.0
# Sentence 794 Probability: 0.0
# Sentence 795 Probability: 0.0
# Sentence 796 Probability: 0.0
# Sentence 797 Probability: 0.0
# Sentence 798 Probability: 0.0
# Sentence 799 Probability: 0.0
# Sentence 800 Probability: 0.0
# Sentence 801 Probability: 0.0
# Sentence 802 Probability: 0.0
# Sentence 803 Probability: 0.0
# Sentence 804 Probability: 0.0
# Sentence 805 Probability: 0.0
# Sentence 806 Probability: 0.0
# Sentence 807 Probability: 0.0
# Sentence 808 Probability: 0.0
# Sentence 809 Probability: 0.0
# Sentence 810 Probability: 0.0
# Sentence 811 Probability: 0.0
# Sentence 812 Probability: 0.0
# Sentence 813 Probability: 0.0
# Sentence 814 Probability: 0.0
# Sentence 815 Probability: 0.0
# Sentence 816 Probability: 0.0
# Sentence 817 Probability: 0.0
# Sentence 818 Probability: 0.0
# Sentence 819 Probability: 0.0
# Sentence 820 Probability: 0.0
# Sentence 821 Probability: 0.0
# Sentence 822 Probability: 0.0
# Sentence 823 Probability: 0.0
# Sentence 824 Probability: 0.0
# Sentence 825 Probability: 0.0
# Sentence 826 Probability: 0.0
# Sentence 827 Probability: 0.0
# Sentence 828 Probability: 0.0
# Sentence 829 Probability: 0.0
# Sentence 830 Probability: 0.0
# Sentence 831 Probability: 0.0
# Sentence 832 Probability: 0.0
# Sentence 833 Probability: 0.0
# Sentence 834 Probability: 0.0
# Sentence 835 Probability: 0.0
# Sentence 836 Probability: 0.0
# Sentence 837 Probability: 0.0
# Sentence 838 Probability: 0.0
# Sentence 839 Probability: 0.0
# Sentence 840 Probability: 0.0
# Sentence 841 Probability: 0.0
# Sentence 842 Probability: 0.0
# Sentence 843 Probability: 0.0
# Sentence 844 Probability: 0.0
# Sentence 845 Probability: 0.0
# Sentence 846 Probability: 0.0
# Sentence 847 Probability: 0.0
# Sentence 848 Probability: 0.0
# Sentence 849 Probability: 0.0
# Sentence 850 Probability: 0.0
# Sentence 851 Probability: 0.0
# Sentence 852 Probability: 0.0
# Sentence 853 Probability: 0.0
# Sentence 854 Probability: 0.0
# Sentence 855 Probability: 0.0
# Sentence 856 Probability: 0.0
# Sentence 857 Probability: 0.0
# Sentence 858 Probability: 0.0
# Sentence 859 Probability: 0.0
# Sentence 860 Probability: 0.0
# Sentence 861 Probability: 0.0
# Sentence 862 Probability: 0.0
# Sentence 863 Probability: 0.0
# Sentence 864 Probability: 0.0
# Sentence 865 Probability: 0.0
# Sentence 866 Probability: 0.0
# Sentence 867 Probability: 0.0
# Sentence 868 Probability: 0.0
# Sentence 869 Probability: 0.0
# Sentence 870 Probability: 0.0
# Sentence 871 Probability: 0.0
# Sentence 872 Probability: 0.0
# Sentence 873 Probability: 0.0
# Sentence 874 Probability: 0.0
# Sentence 875 Probability: 0.0
# Sentence 876 Probability: 0.0
# Sentence 877 Probability: 0.0
# Sentence 878 Probability: 0.0
# Sentence 879 Probability: 0.0
# Sentence 880 Probability: 0.0
# Sentence 881 Probability: 0.0
# Sentence 882 Probability: 0.0
# Sentence 883 Probability: 0.0
# Sentence 884 Probability: 0.0
# Sentence 885 Probability: 0.0
# Sentence 886 Probability: 0.0
# Sentence 887 Probability: 0.0
# Sentence 888 Probability: 0.0
# Sentence 889 Probability: 0.0
# Sentence 890 Probability: 0.0
# Sentence 891 Probability: 0.0
# Sentence 892 Probability: 0.0
# Sentence 893 Probability: 0.0
# Sentence 894 Probability: 0.0
# Sentence 895 Probability: 0.0
# Sentence 896 Probability: 0.0
# Sentence 897 Probability: 0.0
# Sentence 898 Probability: 0.0
# Sentence 899 Probability: 0.0
# Sentence 900 Probability: 0.0
# Sentence 901 Probability: 0.0
# Sentence 902 Probability: 0.0
# Sentence 903 Probability: 0.0
# Sentence 904 Probability: 0.0
# Sentence 905 Probability: 0.0
# Sentence 906 Probability: 0.0
# Sentence 907 Probability: 0.0
# Sentence 908 Probability: 0.0
# Sentence 909 Probability: 0.0
# Sentence 910 Probability: 0.0
# Sentence 911 Probability: 0.0
# Sentence 912 Probability: 0.0
# Sentence 913 Probability: 0.0
# Sentence 914 Probability: 0.0
# Sentence 915 Probability: 0.0
# Sentence 916 Probability: 0.0
# Sentence 917 Probability: 0.0
# Sentence 918 Probability: 0.0
# Sentence 919 Probability: 0.0
# Sentence 920 Probability: 0.0
# Sentence 921 Probability: 0.0
# Sentence 922 Probability: 0.0
# Sentence 923 Probability: 0.0
# Sentence 924 Probability: 0.0
# Sentence 925 Probability: 0.0
# Sentence 926 Probability: 0.0
# Sentence 927 Probability: 0.0
# Sentence 928 Probability: 0.0
# Sentence 929 Probability: 0.0
# Sentence 930 Probability: 0.0
# Sentence 931 Probability: 0.0
# Sentence 932 Probability: 0.0
# Sentence 933 Probability: 0.0
# Sentence 934 Probability: 0.0
# Sentence 935 Probability: 0.0
# Sentence 936 Probability: 0.0
# Sentence 937 Probability: 0.0
# Sentence 938 Probability: 0.0
# Sentence 939 Probability: 0.0
# Sentence 940 Probability: 0.0
# Sentence 941 Probability: 0.0
# Sentence 942 Probability: 0.0
# Sentence 943 Probability: 0.0
# Sentence 944 Probability: 0.0
# Sentence 945 Probability: 0.0
# Sentence 946 Probability: 0.0
# Sentence 947 Probability: 0.0
# Sentence 948 Probability: 0.0
# Sentence 949 Probability: 0.0
# Sentence 950 Probability: 0.0
# Sentence 951 Probability: 0.0
# Sentence 952 Probability: 0.0
# Sentence 953 Probability: 0.0
# Sentence 954 Probability: 0.0
# Sentence 955 Probability: 0.0
# Sentence 956 Probability: 0.0
# Sentence 957 Probability: 0.0
# Sentence 958 Probability: 0.0
# Sentence 959 Probability: 0.0
# Sentence 960 Probability: 0.0
# Sentence 961 Probability: 0.0
# Sentence 962 Probability: 0.0
# Sentence 963 Probability: 0.0
# Sentence 964 Probability: 0.0
# Sentence 965 Probability: 0.0
# Sentence 966 Probability: 0.0
# Sentence 967 Probability: 0.0
# Sentence 968 Probability: 0.0
# Sentence 969 Probability: 0.0
# Sentence 970 Probability: 0.0
# Sentence 971 Probability: 0.0
# Sentence 972 Probability: 0.0
# Sentence 973 Probability: 0.0
# Sentence 974 Probability: 0.0
# Sentence 975 Probability: 0.0
# Sentence 976 Probability: 0.0
# Sentence 977 Probability: 0.0
# Sentence 978 Probability: 0.0
# Sentence 979 Probability: 0.0
# Sentence 980 Probability: 0.0
# Sentence 981 Probability: 0.0
# Sentence 982 Probability: 0.0
# Sentence 983 Probability: 0.0
# Sentence 984 Probability: 0.0
# Sentence 985 Probability: 0.0
# Sentence 986 Probability: 0.0
# Sentence 987 Probability: 0.0
# Sentence 988 Probability: 0.0
# Sentence 989 Probability: 0.0
# Sentence 990 Probability: 0.0
# Sentence 991 Probability: 0.0
# Sentence 992 Probability: 0.0
# Sentence 993 Probability: 0.0
# Sentence 994 Probability: 0.0
# Sentence 995 Probability: 0.0
# Sentence 996 Probability: 0.0
# Sentence 997 Probability: 0.0
# Sentence 998 Probability: 0.0
# Sentence 999 Probability: 0.0
# Sentence 1000 Probability: 0.0
#
#  Uni Gram Corpus Perplexity: 1.0091880943590672
#
#  Smoothed Uni Gram Corpus Perplexity: 1.0091651619267774
#
#  BI Gram Corpus Perplexity: 1.0
#
#  Smoothed BI Gram Corpus Perplexity: 1.0

# %% [markdown]
# ## Questions

# %%
# Question 1
print("1. Sentence Length in Unigram vs. Bigram Models:")
print("   - Unigram model generates sentences independently, controlled by word probabilities.")
print("   - Bigram models consider word dependencies, resulting in more coherent sentence lengths.")

# Question 2
print("\n2. Probability of Generated Sentences:")
print("   - Yes, models assign different probabilities due to independent vs. contextual word generation.")
print("   - Bigram models, especially smoothed ones, provide more accurate contextual probabilities.")

# Question 3
print("\n3. Comparison of Sentence Realism:")
print("   - Smoothed bigram model is expected to produce more realistic sentences.")
print("   - Smoothing techniques enhance the representation of language structure.")

# Question 4
print("\nPerplexity Comparison:")
print("1. Unigram Model Corpus Perplexity:", 1.009)
print("2. Smoothed Unigram Model Corpus Perplexity:", 1.009)
print("3. Bigram Model Corpus Perplexity:", 1.0)
print("4. Smoothed Bigram Model Corpus Perplexity:", 1.0)
print("\nThe lower the perplexity, the better the model predicts the test data. In this case, bigram models outperform unigram models.")
# Out:
# 1. Sentence Length in Unigram vs. Bigram Models:
#    - Unigram model generates sentences independently, controlled by word probabilities.
#    - Bigram models consider word dependencies, resulting in more coherent sentence lengths.
#
# 2. Probability of Generated Sentences:
#    - Yes, models assign different probabilities due to independent vs. contextual word generation.
#    - Bigram models, especially smoothed ones, provide more accurate contextual probabilities.
#
# 3. Comparison of Sentence Realism:
#    - Smoothed bigram model is expected to produce more realistic sentences.
#    - Smoothing techniques enhance the representation of language structure.
#
# Perplexity Comparison:
# 1. Unigram Model Corpus Perplexity: 1.009
# 2. Smoothed Unigram Model Corpus Perplexity: 1.009
# 3. Bigram Model Corpus Perplexity: 1.0
# 4. Smoothed Bigram Model Corpus Perplexity: 1.0
#
# The lower the perplexity, the better the model predicts the test data. In this case, bigram models outperform unigram models.
