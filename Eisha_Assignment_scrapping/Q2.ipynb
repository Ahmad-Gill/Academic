# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome()
driver.get("https://www.youtube.com/")

# %%
search_box = driver.find_element(By.XPATH, '//*[@id="center"]/yt-searchbox/div[1]/form/input')
search_box.send_keys("Deepseek")
search_box.send_keys(Keys.RETURN)
time.sleep(5)

# %%
max_scrolls = 1
csv_filename = "youtube.csv"
unique_movies = set()
for _ in range(max_scrolls):
    print("Scrolling down...")
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(5)  

    main_div = driver.find_element(By.XPATH, "//*[@id='contents']")
    movies = main_div.find_elements(By.XPATH, "//*[@id='contents']/ytd-video-renderer")

    print(len(movies))

    for movie in movies:
        try:
            movie_anchor = movie.find_element(By.ID, "video-title")
            mov_url = movie_anchor.get_attribute("href")
            movie_title = movie_anchor.text.strip()
            views = movie.find_element(By.XPATH, ".//*[@id='metadata-line']/span[1]").text.strip()
            channel = movie.find_element(By.XPATH, ".//*[@id='text']/a").text.strip()
            date = movie.find_element(By.XPATH, ".//*[@id='metadata-line']/span[2]").text.strip()
            duration_element = movie.find_elements(By.XPATH, ".//*[@id='overlays']/ytd-thumbnail-overlay-time-status-renderer/div[1]/badge-shape/div")
            duration = duration_element[0].text.strip() if duration_element else "N/A"

            movie_entry = (movie_title, mov_url, views, channel, date, duration)

            if movie_entry not in unique_movies:
                unique_movies.add(movie_entry)

        except Exception as e:
            print(f"Skipping movie due to error: {e}")

df = pd.DataFrame(list(unique_movies), columns=["Title", "URL", "Views", "Channel", "Upload Date", "Duration"])
df.to_csv(csv_filename, index=False)
print(f"Final CSV saved: {csv_filename} with {len(unique_movies)} unique movies.")
# Out:
# Scrolling down...
# 530
# Final CSV saved: youtube.csv with 519 unique movies.

# %%
data = pd.read_csv("youtube.csv")
data
# Out:
#                                                  Title  \
# 0    How To Earn 200$ with Deepseek AI (FREE) | Cre...
# 1    รู้จัก DeepSeek AI น้องใหม่ ทำไมถึงมาแรงยิ่งกว...
# 2    DeepSeek AI Kya Hai? #deepseek #sscutkarsh #sh...
# 3    Should you sell Nvidia’s stock? #nvidia #ai #d...
# 4    Deepseek R1 671b Local Ai Takes How Much Power...
# ..                                                 ...
# 514               China caught LYING about DeepSeek Ai
# 515  DeepSeek Vs ChatGPT For AI Content Creators | ...
# 516  Deepseek R1 | एक चाइनीज़ App ने Donald Trump औ...
# 517  DeepSeek-R1 Paper Explained - A New RL LLMs Er...
# 518  DeepSeek on Apple Silicon in depth | 4 MacBook...
#
#                                                    URL       Views  Channel  \
# 0    https://www.youtube.com/watch?v=6Y287V4PPUI&pp...   18K views      NaN
# 1    https://www.youtube.com/watch?v=OMi23SYvfO4&pp...   87K views      NaN
# 2           https://www.youtube.com/shorts/i3RQV3mK3KY   28K views      NaN
# 3           https://www.youtube.com/shorts/KqmSIIISTDw   25K views      NaN
# 4           https://www.youtube.com/shorts/8bPn0Yl-PK4  101K views      NaN
# ..                                                 ...         ...      ...
# 514  https://www.youtube.com/watch?v=ZuMPPf3D5R8&pp...  347K views      NaN
# 515  https://www.youtube.com/watch?v=3Ga8hu4PXhw&pp...   24K views      NaN
# 516  https://www.youtube.com/watch?v=k_kjMc-bZEQ&pp...  277K views      NaN
# 517  https://www.youtube.com/watch?v=DCqqCLlsIBU&pp...   74K views      NaN
# 518  https://www.youtube.com/watch?v=jdgy9YUSv0s&pp...  166K views      NaN
#
#      Upload Date Duration
# 0     4 days ago      NaN
# 1    2 weeks ago      NaN
# 2    2 weeks ago      NaN
# 3    2 weeks ago      NaN
# 4    2 weeks ago      NaN
# ..           ...      ...
# 514  2 weeks ago      NaN
# 515   2 days ago     9:51
# 516  2 weeks ago      NaN
# 517  3 weeks ago      NaN
# 518  11 days ago    26:27
#
# [519 rows x 6 columns]

# %%
input_csv = "youtube.csv"
output_csv = "youtube_details.csv"

df = pd.read_csv(input_csv)
driver = webdriver.Chrome()
movie_details = []

for index, row in df.iterrows():
    movie_url = row["URL"]
    video_name = row["Title"]
    print(f"Scraping details for: {video_name}")
    driver.get(movie_url)
    time.sleep(5)

    try:
        description_elements = driver.find_elements(By.XPATH, '//*[@id="attributed-snippet-text"]/span/span')
        description = " ".join([desc.text.strip() for desc in description_elements]) if description_elements else "N/A"

        try:
            likes = driver.find_element(By.XPATH, '//*[@id="top-level-buttons-computed"]/segmented-like-dislike-button-view-model/yt-smartimation/div/div/like-button-view-model/toggle-button-view-model/button-view-model/button/yt-touch-feedback-shape/div/div[2]').text.strip()
        except:
            likes = "N/A"

        try:
            channel = driver.find_element(By.XPATH, '//*[@id="text"]/a').text.strip()
        except:
            channel = "N/A"

        movie_details.append({
            "Title": video_name,
            "URL": movie_url,
            "Channel": channel,
            "Likes": likes,
            "Description": description
        })

    except Exception as e:
        print(f"Skipping due to error: {e}")

df_details = pd.DataFrame(movie_details)
df_details.to_csv(output_csv, index=False)

print(f"Video details saved in {output_csv}")
# Out:
# Scraping details for: How To Earn 200$ with Deepseek AI (FREE) | Create Tool Website Using Deepseek AI | Deepseek R1
# Scraping details for: รู้จัก DeepSeek AI น้องใหม่ ทำไมถึงมาแรงยิ่งกว่าม้ามืด I Ceemeagain
# Scraping details for: DeepSeek AI Kya Hai? #deepseek #sscutkarsh #shorts
# Scraping details for: Should you sell Nvidia’s stock? #nvidia #ai #deepseek #stockmarket
# Scraping details for: Deepseek R1 671b Local Ai Takes How Much Power?! 👀⚡💸
# Scraping details for: 【DeepSeek】米テックを抜く？AI専門家「超すごい」開発コストの安さとド根性に驚愕…スターゲート計画は？東大で7千人受講希望の研究者が解説｜アベヒル
# Scraping details for: DeepSeek stole our tech... says OpenAI
# Scraping details for: HOW TO MAKE MONEY WITH GOOGLE & DEEPSEEK (Step By Step Tutorial)
# Scraping details for: DeepSeek-R1 Logo Design is INSANE 🐳💥
# Scraping details for: DEEPSEEK AI CHINA KALAHKAN ChatGPT DAN BIKIN SAHAM AMERIKA ANJLOK RIBUAN TRILIUN
# Scraping details for: Deepseek DEEP Agent: This AI Agent CAN CONTROL 1000s OF BROWSERS AT ONCE! (Deep Research)
# Scraping details for: How Did China Build AI So Fast? #shorts #mangeshshinde #deepseek
# Scraping details for: 1Task = $166 Earn DeepSeek Make Money Online
# Scraping details for: DeepSeek R1 on M4 MacBook Pro | fail
# Scraping details for: INSANE Deepseek R1 Bias! Use with caution #genai #deepseek #opensource
# Scraping details for: Deepseek ¿Sabes la verdad? - Lo instalamos localmente en una Orange Pi 5 Max
# Scraping details for: DeepSeek: Ultimate $1944/Day DeepSeek AI Automation MASTERCLASS (Make Money Online 2025)
# Scraping details for: La IA china DeepSeek agita las Bolsas y desafía a Silicon Valley
# Scraping details for: ทุกคนพูดถึง DeepSeek
# Scraping details for: What the DeepSeek AI Fever Says About China's Economy
# Scraping details for: 【廣東話】詳解DeepSeek憑什麼打贏美國AI巨頭：廉價、高效LLM證明拜登、特朗普「都錯了」？｜Jack Talk｜人工智能｜ChatGPT｜OpenAI｜o3-mini vs R1
# Scraping details for: DeepSeek 🐋 End of ChatGPT? 😱 | Madan Gowri | Tamil | MG Squad 🖖
# Scraping details for: 🤯 AI போரை தொடங்கியதா சீனா? 😱 China's DeepSeek சம்பவம் | Mr.GK
# Scraping details for: Chinese AI app DeepSeek shakes tech industry, wiping half a trillion dollars off Nvidia | DW News
# Scraping details for: නොමිලේ දෙන DeepSeek AI එකේ ඇත්තම කතාව මොකක්ද ?
# Scraping details for: DeepSeek R1 EXPOSED in 2 Minutes Flat!
# Scraping details for: Deepseek valla loss ayna 😢 #deepseek #ai #chatgpt #telugu
# Scraping details for: US Navy Bans DeepSeek AI Over Security Concerns
# Scraping details for: 中国製の人工知能"DeepSeek"をRaspberry Pi 5で動かす! ChatGPTより高性能?
# Scraping details for: DeepSeek is BETTER than ChatGPT ?! *Reality*
# Scraping details for: كيف هزت DeepSeek العالم؟ هل يتفوق الذكاء الصيني على عمالقة أمريكا؟
# Scraping details for: DeepSeek R1 - Real Money | Zero Competition Calculator Tools | Full Tutorial
# Scraping details for: DeepSeek打破价格壁垒 大马应如何借机转型? | 八点最热报 06/02/2025
# Scraping details for: DeepSeek ve yapay zeka: Çin ABD’yi nasıl sarstı?
# Scraping details for: Illustrated DeepSeek-R1 And Live Q&A With Jay Alammar
# Scraping details for: Learn how ChatGPT and DeepSeek models work: How Transformer LLMs Work [Free Course]
# Scraping details for: Is DeepSeek Lying to you? #shorts #wireshark #deepseek #privacy #cybersecurity
# Scraping details for: DeepSeek Drama, Explained
# Scraping details for: La forma más FÁCIL de Instalar DeepSeek en VSCode
# Scraping details for: Deepseek Computer Use AI Agents are CRAZY (FREE!) 🤯
# Scraping details for: Illustrated DeepSeek-R1 And Live Q&A With Jay Alammar
# Scraping details for: NEW Deepseek AI Good For Creating Trading Strategies in TradingView and PineScript? (FREE AI)
# Scraping details for: Tiny DeepSeek R1 Clone Beats O1-Preview at Math?! PhD Student's STUNNING Discovery
# Scraping details for: When AI Competes: Deepseek Vs Open AI Explained
# Scraping details for: How to Use DeepSeek AI App Beginners Guide 2025
# Scraping details for: Why the West Hates DeepSeek? | Vantage with Palki Sharma | N18G
# Scraping details for: I Think I Love Deepseek R1
# Scraping details for: DEEPSEEK HUMILIATES CHATGTP! IS THE HYPE REAL? ? OFFICIAL COMPARISON
# Scraping details for: Running FULL DeepSeek R1 671B Locally (Test and Install!)
# Scraping details for: How to Create a Tool Website using Deepseek Ai and Gemini Ai in WordPress | Make Money Online
# Scraping details for: 🤯DeepSeek R1 vs ChatGPT: Who Will Dominate the Future of AI?
# Scraping details for: How China’s New AI Model DeepSeek Is Threatening U.S. Dominance
# Scraping details for: Deepseek R1 Explained by a Retired Microsoft Engineer
# Scraping details for: DeepSeek's New AI Model: A Game-Changer in Open-Source AI?
# Scraping details for: China’s DeepSeek - A Balanced Overview
# Scraping details for: DeepSeek Just Lost to Alibaba’s New AI!
# Scraping details for: الذكاء الاصطناعي اللي دمر الشركات الامريكية - deepseek
# Scraping details for: Deepseek - a cheater? (Exposed)
# Scraping details for: Things You Should Know About Deepseek AI !! #shorts #deepseek
# Scraping details for: 🚨 DEEPSEEK: El TERREMOTO CHINO que NADIE ESPERABA y QUE PUEDE CAMBIARLO TODO. Las TECH se DESPLOMAN
# Scraping details for: DeepSeek R1 成功越狱！无审查、无思想钢印，无政治倾向，突破道德枷锁！AI 真的自由了？附模型下载 | 零度解说
# Scraping details for: Qué es DeepSeek, la IA china más barata que censura y desafía a las tecnológicas de EE. UU.
# Scraping details for: DeepSeek se está garchando a todos.
# Scraping details for: Easiest $125/Hour DeepSeek Tutorial (Make Money Online 2025)
# Scraping details for: CRISE NA BOLSA AMERICANA: A NOVA IA DeepSeek
# Scraping details for: DeepSeek Explained: AI is Changing EVERYTHING!
# Scraping details for: DeepSeek is not just shaking up AI – it’s also shaking up US capitalism
# Scraping details for: How To Dropship With Deepseek (NEW AI METHOD REVEALED)
# Scraping details for: The DARK Reality Of DeepSeek AI🔥🔥🔥
# Scraping details for: NEW DeepSeek-V3 Agents are INSANE!
# Scraping details for: Deep Ai, Market Crash, ki vajah #deepseek
# Scraping details for: اخيرا الوحش الصيني المجاني بالكامل للذكاء الاصطناعي DeepSeek على الاستور | انسى ChatGPT
# Scraping details for: DeepSeek Sparks Global Tech Selloff
# Scraping details for: What is DeepSeek? Low-cost AI model rattles markets
# Scraping details for: DeepSeek Vs Chatgpt | Asal Sach !!
# Scraping details for: Why DeepSeek is so Scary
# Scraping details for: #deepseek is a flashpoint, but part of a larger trend #ai
# Scraping details for: GAMPANG!! Cara Menggunakan Deepseek AI Sang Penakluk ChatGPT
# Scraping details for: Why Can't India Build its Own DeepSeek or ChatGPT? | Vantage with Palki Sharma | N18G
# Scraping details for: DeepSeek R1 Explained to a 10 Year Old
# Scraping details for: State of Play in China:Deepseek's Emergence: What Will the Future of Humanity Look Like?
# Scraping details for: Deepseek-R1 + RooCode: BEST AI Coding Agent! Develop a Full-stack App Without Writing ANY Code!
# Scraping details for: How to use DeepSeek Ai || DeepSeek Ai သုံးနည်း
# Scraping details for: ВСЕ ОБ ЭТОМ ГОВОРЯТ! DeepSeek – главный прорыв в нейросетях 2025
# Scraping details for: 【Deepseek 懶人包】15分鐘廣東話講解DeepSeek深度求索AI 香港用戶無VPN都可以用得 ChatGPT的超勁對手！
# Scraping details for: How DeepSeek achieved its AI breakthrough, Benchmark partner Chetan Puttagunta explains
# Scraping details for: DeepSeek-R1 VS ChatGPT o1: Who wins?
# Scraping details for: DeepSeekचा भारतावर परिणाम होणार का? | What is DeepSeek And Will it Make a Difference in India
# Scraping details for: CHATGPT’YE VEDA! - Çinli DeepSeek nedir? DeepSeek vs ChatGPT!
# Scraping details for: DeepSeek R1 Fully Tested - Insane Performance
# Scraping details for: DeepSeek大模型橫空出世 中國扭轉戰局 AI高耗能高用電 提升各國能源韌性當務之急 中國2040年前欲實現核融合發電 應對AI高耗能 #TVBS文茜的世界周報【#重點回顧】 202502015
# Scraping details for: Build ANYTHING With AI Agents For FREE! (DeepSeek-R1 Beats ChatGPT)
# Scraping details for: DeepSeek News | Chinese AI DeepSeek Is A ‘Wake-Up Call’ for US Tech, Says President Donald Trump
# Scraping details for: So I Tried DeepSeek..
# Scraping details for: DeepSeek世纪骗局给我们的赚钱机会
# Scraping details for: DEEPSEEK LA IA CHINA PONE EN CRISIS LA INDUSTRIA MUNDIAL
# Scraping details for: Deepseek-R1 Deep Research: AI Agent CAN CONTROL Control Thousands of Browsers Simultaneously!
# Scraping details for: ترامب يأمر بتحرك عاجل لمواجهة التطبيق الصيني DeepSeek | #رادار
# Scraping details for: Why Deepseek isn’t a threat to OpenAI 🤔
# Scraping details for: DeepSeek: la herramienta china de inteligencia artificial y sus diferencias con ChatGPT o Gemini
# Scraping details for: What is Deep Seek..? | New AI of China #deepseek #AI #openai
# Scraping details for: DeepSeek You build it first or you build it better Principal in HINDI
# Scraping details for: Macron Reacts to DeepSeek, Says "No Plan to Ban Chinese AI" | Firstpost-France TV Exclusive | N18G
# Scraping details for: Giải mã DeepSeek - Quả bom nguyên tử trong cuộc chiến A.I toàn cầu | VTV24
# Scraping details for: DeepSeek R1: Is Your Job in Danger? (The Truth)
# Scraping details for: OpenAI's nightmare: Deepseek R1 on a Raspberry Pi
# Scraping details for: Börsen-Beben durch neue China-KI: Warum DeepSeek so erfolgreich ist | KI-Experte bei ZDFheute live
# Scraping details for: চীনের ডিপসিক যেভাবে আমেরিকার বাজার শেষ করে দিলো । How DeepSeek challenged America | Enayet Chowdhury
# Scraping details for: DeepSeek R1 vs OpenAI o3-mini vs o1 pro vs Gemini Flash 2.0 Thinking | Lex Fridman Podcast
# Scraping details for: ചൈനയുടെ ഡീപ് സീക്ക് വമ്പ് | Chinese AI startup DeepSeek shakes up Silicon Valley | Out Of Focus
# Scraping details for: DeepSeek R1 - $1000 Again and Again Every Month
# Scraping details for: How did DeepSeek convince Google CEO? Wen Xinyiyan is open to use for free.
# Scraping details for: 챗GPT 대항마, 딥시크 (DeepSeek) 제대로 알고 사용하는 법! 중국의 미친 무료 인공지능 사용 후기
# Scraping details for: China Golpea el Mercado de la Inteligencia Artificial con DeepSeek
# Scraping details for: DeepSeek R1 Cloned for $30?! PhD Student STUNNING Discovery
# Scraping details for: DeepSeek Scam Exposed | DeepSeek Explained | ChatGPT vs DeepSeek | India China USA
# Scraping details for: Siyatha FM MORNING SHOW 2025 01 30 | හලෝ Deepseek.. ලංකාවේ ජනාධිපති කවු ද?
# Scraping details for: How to Use DeepSeek
# Scraping details for: How the NEW DeepSeek AI Strategy Turned $100 into $23K!
# Scraping details for: DeepSeek or ChatGPT?
# Scraping details for: DeepSeek: What Actually Matters (for the everyday user)
# Scraping details for: How to Build an AI App with DeepSeek Using No Code
# Scraping details for: How to Use DeepSeek R1 for Free right now
# Scraping details for: DEEPSEEK: A IA CHINESA QUE DERRETEU A BOLSA DE VALORES AMERICANA
# Scraping details for: China’s DeepSeek Surprise | Trump calls China's DeepSeek AI a "wake-up call" | Samaa TV
# Scraping details for: What is DeepSeek and how is it disrupting global tech?
# Scraping details for: Chi Tiết Cách Dùng DeepSeek Công Cụ AI Mới Khiến Thế Giới Chao Đảo Của Các Pháp Sư Trung Hoa
# Scraping details for: DeepSeek for Coding 🤯
# Scraping details for: Anthropic CEO Reveals New Details About DeepSeek R1
# Scraping details for: Episodio de Emergencia: DeepSeek Puede Cambiarlo TODO - Jon Hernández #LFDE
# Scraping details for: The CORRECT way to use Deepseek R1 with n8n #aiagents #artificialintelligence #ai #nocode #n8n
# Scraping details for: 方脸说：DeepSeek实现了弯道超车了吗？DeepSeek是剽窃还是创新？DeepSeek到底现在是什么水平？知识蒸馏丨chatgpt
# Scraping details for: ŠOKUJÍCÍ: DeepSeek AI (ZDARMA) právě PŘEKONALA ChatGPT-4 a Claude Sonnet 3.5! 🔥
# Scraping details for: 扎克伯格稱DeepSeek很先進，中美AI差距非常小。 #中國 #美國 #china #deepseek #ai #zuckerberg
# Scraping details for: ChatGPT vs DeepSeek: CRAZY Chess
# Scraping details for: DeepSeek vs ChatGPT (o1): Is China's Free LLM Better?
# Scraping details for: Chinas DeepSeek R1 SHOCKS The AI Industry (BEATS OpenAI) DeepSeek R1
# Scraping details for: Stop using ChatGPT and DeepSeek Indian Government tells Finance Ministry Officials #chatgpt #ai
# Scraping details for: DEEPSEEK R1 en tu ordenador (Privado, Fácil y Gratis) 🤯 ¡Tutorial + Demo!
# Scraping details for: DeepSeek, China, OpenAI, NVIDIA, xAI, TSMC, Stargate, and AI Megaclusters | Lex Fridman Podcast #459
# Scraping details for: Chinese AI DeepSeek Censorship Exposed!
# Scraping details for: DeepSeek Panic, US vs China, OpenAI $40B?, and Doge Delivers with Travis Kalanick and David Sacks
# Scraping details for: How To Earn $50/Day From Deepseek AI | Create Tool Website Using Deepseek AI
# Scraping details for: Prince Alwaleed: Trump’s Tariff’s, DeepSeek, & Going From Fox News’ Biggest Investor to Backing X
# Scraping details for: චීනයේ DeepSeek අමෙරිකාව කලඹයි...
# Scraping details for: DeepSeek’s AI should be a ‘wakeup call’: Trump
# Scraping details for: End To End RAG Agent With DeepSeek-R1 And Ollama
# Scraping details for: Deepseek | Deepseek AI | मानवता के लिए एक नई चुनौती | Gopal Verma Sir #shorts
# Scraping details for: Is DeepSeek reading what you type before you hit send? #carterpcs #tech #techtok #techfacts
# Scraping details for: DeepSeek-R1 se Mobile App Kaise Banaye #deepseek #ai #earnmoneyonline #makemoneyonline #money
# Scraping details for: 20 years in jail for using DeepSeek! USA goes NUTS over Chinese AI
# Scraping details for: DeepSeek là gì? Chuyên gia AI giải thích cụ thể, chi tiết, dễ hiểu về DeepSeek
# Scraping details for: Is DeepSeek stealing from OpenAI | Lex Fridman Podcast
# Scraping details for: DeepSeek關鍵工程師潘梓正曾在英偉達實習，美國學者靈魂發問 ：為什麼他選擇中國而不是美國？#DeepSeek #潘梓正 #美國 #china
# Scraping details for: Why DeepSeek is such a big deal? | DeepSeek's impact on the future of AI
# Scraping details for: $500/Month with DeepSeek R1 - Tools Website
# Scraping details for: Deepseek: How To Make $100/day (with PROOF!)🤯
# Scraping details for: How @NVIDIA benefits from DeepSeek #shorts
# Scraping details for: DeepSeek R1: How To Make $499/Monthly Using Deepseek AI & Threads (Make Money Online 2025)
# Scraping details for: Did DeepSeek steal from OpenAI? (lol)
# Scraping details for: DeepSeek's chess skills beat ChatGPT! OpenAI refuses to admit defeat
# Scraping details for: I tested DeepSeek vs. OpenAI-o1 for data science tasks: Here’s what I found.
# Scraping details for: How to Earn $275/Hour with DeepSeek For FREE (Make Money Online 2025)
# Scraping details for: 【摆脱卡顿】DeepSeek全网最全的实战技巧！建议收藏～
# Scraping details for: China’s AI Masterstroke: How DeepSeek is Disrupting the Industry | Vantage with Palki Sharma | N18G
# Scraping details for: DeepSeek vs OpenAi#shorts
# Scraping details for: Deepseek r1 how to use | Deepseek Vs ChatGPT | Telugu | Vamsi Bhavani
# Scraping details for: Never Install DeepSeek r1 Locally before Watching This!
# Scraping details for: Nvidia DeepSeek R1 ChatGPT #money #ai #deepseek #nvidia #chatgpt #rich #richmindset
# Scraping details for: DeepSeek’s networking assembly code issues on SLOW switches #deepseek #openai #nvidia #technews #ai
# Scraping details for: 中国製AI「DeepSeek」について正直言います【ひろゆき切り抜き】
# Scraping details for: DeepSeek：美国科技巨头为何冒险接入？高级玩法、本地部署全解析！| 零度解说
# Scraping details for: What is DeepSeek? #DeepSeek #AI #BBCNews
# Scraping details for: DeepSeek: Why has China’s AI start-up shocked the tech world?
# Scraping details for: If You Ask DeepSeek 4 Questions, You'll NEVER Worry About Money Again | Digital Product Course
# Scraping details for: WHAT IS DEEPSEEK
# Scraping details for: เปิดประวัติ เหลียงเหวินเฟิง ผู้สร้าง ‘DeepSeek’ เขย่าบัลลังก์ AI สหรัฐฯ | Morning Wealth Highlight
# Scraping details for: DeepSeek Reacts to Getting Banned
# Scraping details for: 美國主持人花式稱讚Deepseek:中國連取名字都完爆美國#deepseek #us #china #ai #中國
# Scraping details for: Insane Theoretical Physics Discussion with ChatGPT and DeepSeek
# Scraping details for: Chinese AI chatbot DeepSeek sparks turmoil in US tech markets | BBC News
# Scraping details for: China's Deepseek AI Explained
# Scraping details for: So läuft DeepSeek lokal mit voller Qualität
# Scraping details for: I built a DeepSeek R1 powered VS Code extension…
# Scraping details for: ChatGPT VS DeepSeek - Which Ai Tool is BETTER? 👀 #SHORTS
# Scraping details for: Is Deepseek Sending Data to China? | #deepseek #futureofselling
# Scraping details for: Automate Anything with DeepSeek-R1, here’s how
# Scraping details for: How OPENAI & Nvidia can beat DeepSeek #nvidia #aistocks #technews #deepseek #technology
# Scraping details for: The Government Is Scared Of DeepSeek...
# Scraping details for: DeepSeek Is Insanely Good... (Then I Competed it With ChatGPT)
# Scraping details for: Deepseek R1 671b Running and Testing on a $2000 Local AI Server
# Scraping details for: Che cos’è DeepSeek: il chatbot AI che sfida ChatGpt e l’economia mondiale
# Scraping details for: KIMI AI desarrolla aplicaciones SIN INTERVENCIÓN humana ❌ Adiós a Deepseek, ChatGPT y... ¿al código?
# Scraping details for: DeepSeek R1: The AI That’s 10x Cheaper and Smarter Than ChatGPT #chatgpt #deepseek #shorts
# Scraping details for: The Engineering Unlocks Behind DeepSeek | YC Decoded
# Scraping details for: DeepSeek القصة الكاملة لنموذج الذكاء الاصطناعي الصيني
# Scraping details for: China greift bei KI richtig an: DeepSeek R1 ist Open Source, kostenlos und so gut wie OpenAI o1
# Scraping details for: DeepSeek Just CRUSHED Big Tech AGAIN With JANUS PRO - New SHOCKING AI Model!
# Scraping details for: ChatGPT vs DeepSeek
# Scraping details for: DeepSeek โมเดล AI ม้ามืดจากจีน คู่แข่ง ChatGPT โดยตรง
# Scraping details for: the ONLY way to run Deepseek...
# Scraping details for: DeepSeek AI Shakes Up Nvidia’s Growth Story - Andreas Steno
# Scraping details for: Free LLM that beats DeepSeek… can also generate videos!?
# Scraping details for: DeepSeek AI’s Shocking Impact on Global Markets & AI🔥
# Scraping details for: DeepSeek: Como ganar $143.07 dólares por día con DeepSeek (NUEVO 2025)
# Scraping details for: Was ihr noch nicht über DeepSeek wusstet
# Scraping details for: حصريا كسر 🤖 DeepSeek-R1 بشكل مجاني ( الأغراض التعليمية فقط )
# Scraping details for: Major G7 Country BANS China’s DeepSeek: Fatal Mistake For Western Economies
# Scraping details for: Can DeepSeek R1 Actually Write Good Code?
# Scraping details for: How To Earn Money Online With a Laptop Using DEEPSEEK AI ($130/Day)
# Scraping details for: DeepSeek DESTROYS the AI Industry... r1 model is UNSTOPPABLE...
# Skipping due to error: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=133.0.6943.98)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF613BC6F15+28773]
# 	(No symbol) [0x00007FF613B32600]
# 	(No symbol) [0x00007FF6139C8FAA]
# 	(No symbol) [0x00007FF6139B4DA5]
# 	(No symbol) [0x00007FF6139D973A]
# 	(No symbol) [0x00007FF613A4EFDF]
# 	(No symbol) [0x00007FF613A6EFE2]
# 	(No symbol) [0x00007FF613A47023]
# 	(No symbol) [0x00007FF613A0FF5E]
# 	(No symbol) [0x00007FF613A111E3]
# 	GetHandleVerifier [0x00007FF613F1425D+3490733]
# 	GetHandleVerifier [0x00007FF613F2BA43+3586963]
# 	GetHandleVerifier [0x00007FF613F2147D+3544525]
# 	GetHandleVerifier [0x00007FF613C8C9DA+838442]
# 	(No symbol) [0x00007FF613B3D04F]
# 	(No symbol) [0x00007FF613B39614]
# 	(No symbol) [0x00007FF613B397B6]
# 	(No symbol) [0x00007FF613B28CE9]
# 	BaseThreadInitThunk [0x00007FFC3672E8D7+23]
# 	RtlUserThreadStart [0x00007FFC374FBF2C+44]
#
# Scraping details for: OpenAI Reacts To DeepSeek R1
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[25], line 12
#      10 video_name = row["Title"]
#      11 print(f"Scraping details for: {video_name}")
# ---> 12 driver.get(movie_url)
#      13 time.sleep(5)
#      15 try:
#
# File c:\Users\mahma\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File c:\Users\mahma\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\mahma\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# 	GetHandleVerifier [0x00007FF613BC6F15+28773]
# 	(No symbol) [0x00007FF613B32600]
# 	(No symbol) [0x00007FF6139C8DDC]
# 	(No symbol) [0x00007FF613A0F17F]
# 	(No symbol) [0x00007FF613A47112]
# 	(No symbol) [0x00007FF613A41AA9]
# 	(No symbol) [0x00007FF613A40B59]
# 	(No symbol) [0x00007FF613995595]
# 	GetHandleVerifier [0x00007FF613F1425D+3490733]
# 	GetHandleVerifier [0x00007FF613F2BA43+3586963]
# 	GetHandleVerifier [0x00007FF613F2147D+3544525]
# 	GetHandleVerifier [0x00007FF613C8C9DA+838442]
# 	(No symbol) [0x00007FF613B3D04F]
# 	(No symbol) [0x00007FF6139941AE]
# 	GetHandleVerifier [0x00007FF613F9EDA8+4058872]
# 	BaseThreadInitThunk [0x00007FFC3672E8D7+23]
# 	RtlUserThreadStart [0x00007FFC374FBF2C+44]
