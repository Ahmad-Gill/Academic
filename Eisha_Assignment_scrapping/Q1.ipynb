# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (4.21.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Requirement already satisfied: trio~=0.17 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from selenium) (2024.12.14)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\mahma\appdata\local\programs\python\python312\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome()
driver.get("https://www.rozee.pk/")

# %%
search_box = driver.find_element(By.XPATH, '//*[@id="search"]')
search_box.send_keys("Software Engineer")
search_box.send_keys(Keys.RETURN)
time.sleep(5)

# %%
csv_filename = "rozee_jobs.csv"
unique_jobs = set()
max_pages = 5
for page in range(max_pages):
    print(f"Scraping Page {page + 1}...")
    job_listings = driver.find_element(By.ID, "jobs")
    job_divs = job_listings.find_elements(By.CLASS_NAME, "job")
    for job in job_divs:
        try:
            job_anchor = job.find_element(By.TAG_NAME, "a")
            job_url = job_anchor.get_attribute("href")
            job_title = job_anchor.find_element(By.TAG_NAME, "bdi").text.strip()
            company_elements = job.find_elements(By.CSS_SELECTOR, ".cname a")
            company_name = company_elements[0].text.strip() if company_elements else "N/A"
            location = company_elements[1].text.strip() if len(company_elements) > 1 else "N/A"
            job_entry = (job_title, job_url, company_name, location)
            if job_entry not in unique_jobs:
                unique_jobs.add(job_entry)
        except Exception as e:
            print(f"Skipping job due to error: {e}")
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    time.sleep(5)
    df = pd.DataFrame(list(unique_jobs), columns=["Job Title", "Job URL", "Company Name", "Location"])
    df.to_csv(csv_filename, index=False)
    print(f"Saved {len(unique_jobs)} jobs.")
    try:
        next_button = driver.find_element(By.XPATH, '//*[@id="jobs"]/div[28]/div/ul/li[3]/a')
        next_button.click()
        time.sleep(5)
    except NoSuchElementException:
        print("Next page button not found. Stopping.")
        break

print(f"Final CSV saved: {csv_filename} with {len(unique_jobs)} unique jobs.")
# Out:
# Scraping Page 1...
# Saved 20 jobs.
# Scraping Page 2...
# Saved 35 jobs.
# Next page button not found. Stopping.
# Final CSV saved: rozee_jobs.csv with 35 unique jobs.

# %%
data=pd.read_csv("rozee_jobs.csv")
data
# Out:
#                                       Job Title  \
# 0              Software Engineer - SQL Database
# 1                             Software Engineer
# 2           Software Quality Assurance Engineer
# 3           Software Quality Assurance Engineer
# 4           Software Quality Assurance Engineer
# 5           Software Quality Assurance Engineer
# 6                             Software Engineer
# 7                           IT Support Engineer
# 8                           Mechanical Engineer
# 9                             Software Engineer
# 10                               Civil Engineer
# 11                            Software Engineer
# 12                    Software Support Engineer
# 13                          Mechanical Engineer
# 14                            Software Engineer
# 15                            Software Engineer
# 16                  Principal Software Engineer
# 17        ASP.NET Developer / Software Engineer
# 18                     Senior Software Engineer
# 19                 Full Stack Software Engineer
# 20          Software Quality Assurance Engineer
# 21  Senior Automated Quality Assurance Engineer
# 22                            Software Engineer
# 23                  Software Engineer (Node.Js)
# 24                          IT Support Engineer
# 25                          Electrical Engineer
# 26                              Design Engineer
# 27                          Estimation Engineer
# 28            Senior Frontend Software Engineer
# 29                               Field Engineer
# 30          Software Quality Assurance Engineer
# 31          Software Quality Assurance Engineer
# 32                               Sales Engineer
# 33                            Software Engineer
# 34                       QA Automation Engineer
#
#                                               Job URL  \
# 0   https://www.rozee.pk/the-shams-group-software-...
# 1   https://www.rozee.pk/digi-soft-software-engine...
# 2   https://www.rozee.pk/e2e-worx-software-quality...
# 3   https://www.rozee.pk/broadstone-technologies-s...
# 4   https://www.rozee.pk/musketeers-tech-software-...
# 5   https://www.rozee.pk/modisoft-software-quality...
# 6   https://www.rozee.pk/st-michael-llc-software-e...
# 7   https://www.rozee.pk/mmba-chartered-certified-...
# 8   https://www.rozee.pk/lockersmiths-pvt-ltd-mech...
# 9   https://www.rozee.pk/croem-inc-software-engine...
# 10  https://www.rozee.pk/manpoy-uk-civil-engineer-...
# 11  https://www.rozee.pk/matz-solutions-pvt-ltd-so...
# 12  https://www.rozee.pk/the-shams-group-software-...
# 13  https://www.rozee.pk/nateeq-enterprise-mechani...
# 14  https://www.rozee.pk/softo-tech-software-engin...
# 15  https://www.rozee.pk/universal-technology-syst...
# 16  https://www.rozee.pk/pakistan-single-window-pr...
# 17  https://www.rozee.pk/evolved-tax-aspnet-develo...
# 18  https://www.rozee.pk/pakistan-single-window-se...
# 19  https://www.rozee.pk/szabist-islamabad-campus-...
# 20  https://www.rozee.pk/modisoft-private-limited-...
# 21  https://www.rozee.pk/rayymen-technologies-priv...
# 22  https://www.rozee.pk/xoftex-software-engineer-...
# 23  https://www.rozee.pk/mmc-software-engineer-nod...
# 24  https://www.rozee.pk/hasnain-tanweer-associate...
# 25  https://www.rozee.pk/digilog-software-electric...
# 26  https://www.rozee.pk/fsk-partners-design-engin...
# 27  https://www.rozee.pk/alzayed-shades-and-tents-...
# 28  https://www.rozee.pk/rayymen-technologies-priv...
# 29  https://www.rozee.pk/muslim-aid-field-engineer...
# 30  https://www.rozee.pk/modisoft-pvt-ltd-software...
# 31  https://www.rozee.pk/zam-software-solutions-so...
# 32  https://www.rozee.pk/creative-electronics-auto...
# 33  https://www.rozee.pk/wayne-enterprises-softwar...
# 34  https://www.rozee.pk/computer-house-qa-automat...
#
#                                         Company Name    Location
# 0                                   The Shams Group,  , Pakistan
# 1                                         Digi Soft,     Karachi
# 2                                          E2E Worx,      Lahore
# 3                           Broadstone Technologies,      Lahore
# 4                                   Musketeers Tech,      Lahore
# 5                                          Modisoft,     Karachi
# 6                                   St. Michael Llc,     Karachi
# 7              MMBA Chartered Certified Accountants,   Islamabad
# 8                            Lockersmiths (Pvt) Ltd,  Gujranwala
# 9                                         Croem Inc,   Islamabad
# 10                                        Manpoy UK,      Lahore
# 11                           MATZ Solutions Pvt Ltd,     Karachi
# 12                                  The Shams Group,  , Pakistan
# 13                                Nateeq Enterprise,      Lahore
# 14                                       Softo Tech,   Islamabad
# 15  Universal Technology Systems and Associates LLC,         NaN
# 16                           Pakistan Single Window,     Karachi
# 17                                      Evolved Tax,  , Pakistan
# 18                           Pakistan Single Window,     Karachi
# 19                       SZABIST - Islamabad Campus,   Islamabad
# 20                         Modisoft Private Limited,     Karachi
# 21             Rayymen Technologies Private Limited,         NaN
# 22                                           Xoftex,      Lahore
# 23                                              MMC,   Islamabad
# 24                       Hasnain Tanweer Associates,     Karachi
# 25                                 Digilog Software,      Lahore
# 26                                   FSK & Partners,  , Pakistan
# 27                     Alzayed Shades And Tents LLC,      Lahore
# 28             Rayymen Technologies Private Limited,         NaN
# 29                                       Muslim Aid,     Chitral
# 30                                 Modisoft Pvt Ltd,     Karachi
# 31                           Zam Software Solutions,   Islamabad
# 32                Creative Electronics & Automation,   Islamabad
# 33                                Wayne Enterprises,  , Pakistan
# 34                                   Computer House,      Lahore

# %%
input_csv = "rozee_jobs.csv"
output_csv = "rozee_jobs_details.csv"
df = pd.read_csv(input_csv)
driver = webdriver.Chrome()
job_details = []

for index, row in df.iterrows():
    job_url = row["Job URL"]
    company_name = row["Company Name"]
    job_title = row["Job Title"]
    print(f"Scraping details for: {job_title} ({company_name})")
    driver.get(job_url)
    time.sleep(5) 
    try:
        skills_elements = driver.find_elements(By.XPATH, '//*[@id="jbDetail"]/div[2]/div//a')
        skills = [skill.text.strip() for skill in skills_elements if skill.text.strip()]
        requirements_elements = driver.find_elements(By.XPATH, '//*[@id="jbDetail"]/div[1]/div/ul[2]/li')
        requirements = [req.text.strip() for req in requirements_elements if req.text.strip()]
        try:
            job_type = driver.find_element(By.XPATH, '//*[@id="jbDetail"]/div[3]/div/div[5]/div[2]').text.strip()
        except NoSuchElementException:
            job_type = "N/A"
        job_details.append({
            "Job Title": job_title,
            "Company Name": company_name,
            "Job URL": job_url,
            "Skills": ", ".join(skills),
            "Requirements": "; ".join(requirements),
            "Job Type": job_type
        })

    except Exception as e:
        print(f"Skipping due to error: {e}")
df_details = pd.DataFrame(job_details)
df_details.to_csv(output_csv, index=False)

print(f"Job details saved in {output_csv}")
# Out:
# Scraping details for: Software Engineer - SQL Database (The Shams Group,)
# Scraping details for: Software Engineer (Digi Soft,)
# Scraping details for: Software Quality Assurance Engineer (E2E Worx,)
# Scraping details for: Software Quality Assurance Engineer (Broadstone Technologies,)
# Scraping details for: Software Quality Assurance Engineer (Musketeers Tech,)
# Scraping details for: Software Quality Assurance Engineer (Modisoft,)
# Scraping details for: Software Engineer (St. Michael Llc,)
# Scraping details for: IT Support Engineer (MMBA Chartered Certified Accountants,)
# Scraping details for: Mechanical Engineer (Lockersmiths (Pvt) Ltd,)
# Scraping details for: Software Engineer (Croem Inc,)
# Scraping details for: Civil Engineer (Manpoy UK,)
# Scraping details for: Software Engineer (MATZ Solutions Pvt Ltd,)
# Scraping details for: Software Support Engineer (The Shams Group,)
# Scraping details for: Mechanical Engineer (Nateeq Enterprise,)
# Scraping details for: Software Engineer (Softo Tech,)
# Scraping details for: Software Engineer (Universal Technology Systems and Associates LLC,)
# Scraping details for: Principal Software Engineer (Pakistan Single Window,)
# Scraping details for: ASP.NET Developer / Software Engineer (Evolved Tax,)
# Scraping details for: Senior Software Engineer (Pakistan Single Window,)
# Scraping details for: Full Stack Software Engineer (SZABIST - Islamabad Campus,)
# Scraping details for: Software Quality Assurance Engineer (Modisoft Private Limited,)
# Scraping details for: Senior Automated Quality Assurance Engineer (Rayymen Technologies Private Limited,)
# Scraping details for: Software Engineer (Xoftex,)
# Scraping details for: Software Engineer (Node.Js) (MMC,)
# Scraping details for: IT Support Engineer (Hasnain Tanweer Associates,)
# Scraping details for: Electrical Engineer (Digilog Software,)
# Scraping details for: Design Engineer (FSK & Partners,)
# Scraping details for: Estimation Engineer (Alzayed Shades And Tents LLC,)
# Scraping details for: Senior Frontend Software Engineer (Rayymen Technologies Private Limited,)
# Scraping details for: Field Engineer (Muslim Aid,)
# Scraping details for: Software Quality Assurance Engineer (Modisoft Pvt Ltd,)
# Scraping details for: Software Quality Assurance Engineer (Zam Software Solutions,)
# Scraping details for: Sales Engineer (Creative Electronics & Automation,)
# Scraping details for: Software Engineer (Wayne Enterprises,)
# Scraping details for: QA Automation Engineer (Computer House,)
# Job details saved in rozee_jobs_details.csv

# %%
data=pd.read_csv("rozee_jobs_details.csv")
data
# Out:
#                                       Job Title  \
# 0              Software Engineer - SQL Database
# 1                             Software Engineer
# 2           Software Quality Assurance Engineer
# 3           Software Quality Assurance Engineer
# 4           Software Quality Assurance Engineer
# 5           Software Quality Assurance Engineer
# 6                             Software Engineer
# 7                           IT Support Engineer
# 8                           Mechanical Engineer
# 9                             Software Engineer
# 10                               Civil Engineer
# 11                            Software Engineer
# 12                    Software Support Engineer
# 13                          Mechanical Engineer
# 14                            Software Engineer
# 15                            Software Engineer
# 16                  Principal Software Engineer
# 17        ASP.NET Developer / Software Engineer
# 18                     Senior Software Engineer
# 19                 Full Stack Software Engineer
# 20          Software Quality Assurance Engineer
# 21  Senior Automated Quality Assurance Engineer
# 22                            Software Engineer
# 23                  Software Engineer (Node.Js)
# 24                          IT Support Engineer
# 25                          Electrical Engineer
# 26                              Design Engineer
# 27                          Estimation Engineer
# 28            Senior Frontend Software Engineer
# 29                               Field Engineer
# 30          Software Quality Assurance Engineer
# 31          Software Quality Assurance Engineer
# 32                               Sales Engineer
# 33                            Software Engineer
# 34                       QA Automation Engineer
#
#                                         Company Name  \
# 0                                   The Shams Group,
# 1                                         Digi Soft,
# 2                                          E2E Worx,
# 3                           Broadstone Technologies,
# 4                                   Musketeers Tech,
# 5                                          Modisoft,
# 6                                   St. Michael Llc,
# 7              MMBA Chartered Certified Accountants,
# 8                            Lockersmiths (Pvt) Ltd,
# 9                                         Croem Inc,
# 10                                        Manpoy UK,
# 11                           MATZ Solutions Pvt Ltd,
# 12                                  The Shams Group,
# 13                                Nateeq Enterprise,
# 14                                       Softo Tech,
# 15  Universal Technology Systems and Associates LLC,
# 16                           Pakistan Single Window,
# 17                                      Evolved Tax,
# 18                           Pakistan Single Window,
# 19                       SZABIST - Islamabad Campus,
# 20                         Modisoft Private Limited,
# 21             Rayymen Technologies Private Limited,
# 22                                           Xoftex,
# 23                                              MMC,
# 24                       Hasnain Tanweer Associates,
# 25                                 Digilog Software,
# 26                                   FSK & Partners,
# 27                     Alzayed Shades And Tents LLC,
# 28             Rayymen Technologies Private Limited,
# 29                                       Muslim Aid,
# 30                                 Modisoft Pvt Ltd,
# 31                           Zam Software Solutions,
# 32                Creative Electronics & Automation,
# 33                                Wayne Enterprises,
# 34                                   Computer House,
#
#                                               Job URL  \
# 0   https://www.rozee.pk/the-shams-group-software-...
# 1   https://www.rozee.pk/digi-soft-software-engine...
# 2   https://www.rozee.pk/e2e-worx-software-quality...
# 3   https://www.rozee.pk/broadstone-technologies-s...
# 4   https://www.rozee.pk/musketeers-tech-software-...
# 5   https://www.rozee.pk/modisoft-software-quality...
# 6   https://www.rozee.pk/st-michael-llc-software-e...
# 7   https://www.rozee.pk/mmba-chartered-certified-...
# 8   https://www.rozee.pk/lockersmiths-pvt-ltd-mech...
# 9   https://www.rozee.pk/croem-inc-software-engine...
# 10  https://www.rozee.pk/manpoy-uk-civil-engineer-...
# 11  https://www.rozee.pk/matz-solutions-pvt-ltd-so...
# 12  https://www.rozee.pk/the-shams-group-software-...
# 13  https://www.rozee.pk/nateeq-enterprise-mechani...
# 14  https://www.rozee.pk/softo-tech-software-engin...
# 15  https://www.rozee.pk/universal-technology-syst...
# 16  https://www.rozee.pk/pakistan-single-window-pr...
# 17  https://www.rozee.pk/evolved-tax-aspnet-develo...
# 18  https://www.rozee.pk/pakistan-single-window-se...
# 19  https://www.rozee.pk/szabist-islamabad-campus-...
# 20  https://www.rozee.pk/modisoft-private-limited-...
# 21  https://www.rozee.pk/rayymen-technologies-priv...
# 22  https://www.rozee.pk/xoftex-software-engineer-...
# 23  https://www.rozee.pk/mmc-software-engineer-nod...
# 24  https://www.rozee.pk/hasnain-tanweer-associate...
# 25  https://www.rozee.pk/digilog-software-electric...
# 26  https://www.rozee.pk/fsk-partners-design-engin...
# 27  https://www.rozee.pk/alzayed-shades-and-tents-...
# 28  https://www.rozee.pk/rayymen-technologies-priv...
# 29  https://www.rozee.pk/muslim-aid-field-engineer...
# 30  https://www.rozee.pk/modisoft-pvt-ltd-software...
# 31  https://www.rozee.pk/zam-software-solutions-so...
# 32  https://www.rozee.pk/creative-electronics-auto...
# 33  https://www.rozee.pk/wayne-enterprises-softwar...
# 34  https://www.rozee.pk/computer-house-qa-automat...
#
#                                                Skills  \
# 0   End to End Sales, Microsoft SQL Database, Soft...
# 1               AngularJS, MVC, RESTful APIs, ASP.net
# 2   Software Quality Checking, Software Quality As...
# 3   Software Quality Review, Agile Programming, So...
# 4   Test Automation, Selenium, Jira Configuration,...
# 5                                 Performance Testing
# 6                               Java, C++, JavaScript
# 7   Microsoft Online, IT Infrastructure Management...
# 8   Team Building, MS Excel, Production Coordinati...
# 9                                              DotNet
# 10          Staad Pro, TEKLA, AutoCAD Design Software
# 11  NodeJs, React, CSS, HTML, Executing Content, A...
# 12  Software Development, T-SQL, MySQL Server, .Ne...
# 13  MEP Engineering, AutoCAD Design Software, Comm...
# 14  Abilities Of Team Work, Knowledge of AI, Knowl...
# 15  Jira Configuration, Backend Development, Front...
# 16  ASP.net, .NET Core, DOCKER, Bootstrap, Rest AP...
# 17  Microsoft SQL Server, ASP.net, C, #Front-End C...
# 18  jQuery, ASP.net, Software Development, JavaScr...
# 19                           MS SQL, C, #MVC, ASP.net
# 20  Load Testing, Regression Testing, Python, Perf...
# 21  Software Quality Assurance, Unit Testing, Sele...
# 22                    AngularJS, .Net, Microsoft .NET
# 23  Node.js, RESTful APIs, Mongodb, PostgreSQL, CI...
# 24  CCNP Security, Windows Administration, Server ...
# 25  Electric Circuit, Circuit Design Knowledge, So...
# 26    Revit, BIM, Navisworks, AutoCAD Design Software
# 27  Microsoft Project, Primavera, AutoCAD Design S...
# 28  React JS, Frontend Development, JavaScript, Gi...
# 29  Liaising Skills, Project Management, Interpers...
# 30                                Performance Testing
# 31  Software Quality Management, Software Life Cyc...
# 32  Electrical Controls Knowledge, iOT, Relationsh...
# 33                                         JavaScript
# 34  Software Quality Review, Software Quality Mana...
#
#                                          Requirements             Job Type
# 0   Bachelors degree in Computer Science or releva...  Full Time/Permanent
# 1                                                 NaN  Full Time/Permanent
# 2                                                 NaN  Full Time/Permanent
# 3   Strong knowledge of Software QA tools and proc...  Full Time/Permanent
# 4                                                 NaN              2 Years
# 5                                                 NaN              2 Years
# 6                                                 NaN        No Preference
# 7                                                 NaN  Full Time/Permanent
# 8                                                 NaN  Full Time/Permanent
# 9                                                 NaN              5 Years
# 10  Bachelor's degree in Civil Engineering from a ...  Full Time/Permanent
# 11  Minimum 1 year of professional experience in s...  Full Time/Permanent
# 12  Proficient with GIT, C#, .NET, and Microsoft S...  Full Time/Permanent
# 13  Learn and develop skills in eQUEST energy mode...  Full Time/Permanent
# 14                                                NaN             Contract
# 15                                                NaN  Full Time/Permanent
# 16  Bachelor’s degree in any discipline, preferred...  Full Time/Permanent
# 17                                                NaN  Full Time/Permanent
# 18  Bachelors Computer Science / Information Techn...             Contract
# 19  Proficiency in ASP.Net and MVC-based developme...  Full Time/Permanent
# 20                                                NaN              2 Years
# 21  Bachelor’s degree in Software Engineering, Com...  Full Time/Permanent
# 22  Analyze, design, and develop tests and test-au...  Full Time/Permanent
# 23                                                NaN              5 Years
# 24                                                NaN            Part Time
# 25  Sales Operator ( Customer Care/Helpline); Tech...    First Shift (Day)
# 26                                                NaN  Full Time/Permanent
# 27                                                NaN  Full Time/Permanent
# 28  Bachelor’s degree in computer science, informa...  Full Time/Permanent
# 29  Conduct a technical assessment for the develop...  Full Time/Permanent
# 30                                                NaN              2 Years
# 31  Develop written test plans, test cases, and sc...    First Shift (Day)
# 32                                                NaN  Full Time/Permanent
# 33                                                NaN        No Preference
# 34  The ideal candidate should have 6 months to 1 ...  Full Time/Permanent

# %% [markdown]
# # ----------------------------Further Analysis------------------------

# %%
def most_common(items):
    counts = {}
    for item in items:
        counts[item] = counts.get(item, 0) + 1
    return sorted(counts.items(), key=lambda x: x[1], reverse=True)[:10]

jobs_df = pd.read_csv("rozee_jobs.csv")
print(most_common(jobs_df["Job Title"]))

job_details_df = pd.read_csv("rozee_jobs_details.csv")
all_skills = []

for skills in job_details_df["Skills"].dropna():
    all_skills.extend(skills.split(","))

print(most_common(all_skills))
# Out:
# [('Software Engineer', 8), ('Software Quality Assurance Engineer', 7), ('IT Support Engineer', 2), ('Mechanical Engineer', 2), ('Software Engineer - SQL Database', 1), ('Civil Engineer', 1), ('Software Support Engineer', 1), ('Principal Software Engineer', 1), ('ASP.NET Developer / Software Engineer', 1), ('Senior Software Engineer', 1)]
# [(' JavaScript', 5), (' HTML', 4), (' ASP.net', 4), (' Software Quality Review', 4), (' Communication Skills', 4), (' AutoCAD Design Software', 4), (' C', 4), (' Software Life Cycle Testing', 3), (' Software Development', 2), ('AngularJS', 2)]
